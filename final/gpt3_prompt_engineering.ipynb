# %% [markdown]
# # AIPI531 Final Project
#
# ### Project: LLMs for Recommendation
# ### Team member: Tianyi, Echo, Jiaxin

# %% [markdown]
#   ## Import required python packages

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)

# %%
import time
import numpy as np
import json
import openai
import random
import argparse
from google.colab import drive

# %%
rseed = 2023
random.seed(rseed)

# %% [markdown]
# ## Assign OpenAI APIs && Keys

# %%
open_ai_keys = ['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']
openai.api_base = "https://api.openai.com/v1"


open_ai_keys_index = 0
openai.api_key = open_ai_keys[open_ai_keys_index]

# %% [markdown]
#   ## Mount file system && load dataset

# %%
# Connect to my drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def read_json(file):
    with open(file) as f:
        return json.load(f)

def write_json(data, file):
    with open(file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

# %%
# Download the MovieLens100K dataset from:
# https://github.com/AGI-Edgerunners/LLM-Next-Item-Rec/blob/main/ml_100k.json
data_ml_100k = read_json("/content/drive/My Drive/Courses/AIPI531/AIPI_Final_Project/ml_100k.json")

# %%
print(data_ml_100k[0][0])
print(data_ml_100k[1])
print(len(data_ml_100k))
# Out:
# My Best Friend's Wedding | The English Patient | Face/Off | Psycho | The Princess Bride | Kids | Kids in the Hall: Brain Candy | Scream | The Craft | The Rock | The Shining | Mission: Impossible | Reality Bites | Aliens | Indiana Jones and the Last Crusade | One Flew Over the Cuckoo's Nest | In the Name of the Father | Return of the Jedi | The Silence of the Lambs | The Usual Suspects | Dances with Wolves | Monty Python's Life of Brian | Monty Python and the Holy Grail | The Full Monty | Clockwork Orange, A | Apocalypse Now | Trainspotting | The Doors | Mr. Holland's Opus | Independence Day (ID4) | Liar Liar | Titanic | What's Eating Gilbert Grape | The Saint | Donnie Brasco | The Empire Strikes Back | Beautiful Girls | Mars Attacks! | Broken Arrow | Amistad | The Long Kiss Goodnight | French Kiss | The Maltese Falcon | Dazed and Confused | Strange Days
# ["The Sunchaser | Jackie Brown | Scream 2 | Conspiracy Theory | Hoodlum | Soul Food | Flubber | Kull the Conqueror | Wishmaster | Kull the Conqueror | City of Industry | L.A. Confidential | Mad City | The Man Who Knew Too Little | Sphere | In the Company of Men | In & Out | Mimic | Gang Related | Spice World | My Best Friend's Wedding | I'm Not Rappaport | Trial and Error | Ulee's Gold | Cop Land | Playing God | I Know What You Did Last Summer | Surviving the Game | The Game | Deep Rising | Hard Rain | Firestorm | Seven Years in Tibet | Lost in Space | U.S. Marshalls | Good Will Hunting | Gandhi | Star Wars | Heat | Wag the Dog | Primal Fear | The Rainmaker | Con Air | The Godfather | Schindler's List | G.I. Jane | Bean | Hard Eight | Red Corner | Anaconda", 'Primary Colors']
# 943

# %% [markdown]
# ## Preprocess the MovieLens100K dataset

# %%
u_item_dict = {}
u_item_p = 0
for elem in data_ml_100k:
    # for watched movies of every user
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in u_item_dict:
            u_item_dict[movie] = u_item_p
            u_item_p +=1
#print (len(u_item_dict))
u_item_len = len(u_item_dict)

user_list = []
for i, elem in  enumerate(data_ml_100k):
    item_hot_list = [0 for ii in range(u_item_len)]
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        item_pos = u_item_dict[movie]
        item_hot_list[item_pos] = 1
    user_list.append(item_hot_list)
user_matrix = np.array(user_list)
user_matrix_sim = np.dot(user_matrix, user_matrix.transpose())

## popularity of each movie
pop_dict = {}
for elem in data_ml_100k:
    # elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in pop_dict:
              pop_dict[movie] = 0
        pop_dict[movie] += 1



i_item_dict = {}
i_item_id_list = []
i_item_user_dict = {}
i_item_p = 0
for i, elem in  enumerate(data_ml_100k):
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in i_item_user_dict:
            item_hot_list = [0. for ii in range(len(data_ml_100k))]
            i_item_user_dict[movie] = item_hot_list
            i_item_dict[movie] = i_item_p
            i_item_id_list.append(movie)
            i_item_p+=1
#         item_pos = item_dict[movie]
        i_item_user_dict[movie][i] += 1
#     user_list.append(item_hot_list)
i_item_s_list = []
for item in i_item_id_list:
    i_item_s_list.append(i_item_user_dict[item])
#     print (sum(item_user_dict[item]))
item_matrix = np.array(i_item_s_list)
# calculate the simularity
item_matrix_sim = np.dot(item_matrix, item_matrix.transpose())

id_list = list(range(0,len(data_ml_100k)))

# %% [markdown]
# ## Define user filtering

# %%
### user filtering
def sort_uf_items(target_seq, us, num_u, num_i):

    candidate_movies_dict = {}
    sorted_us = sorted(list(enumerate(us)), key=lambda x: x[-1], reverse=True)[:num_u]
    dvd = sum([e[-1] for e in sorted_us])
    for us_i, us_v in sorted_us:
        us_w = us_v * 1.0/dvd
#         print (us_i)
        us_elem = data_ml_100k[us_i]
#         print (us_elem[0])
#         assert 1==0
        us_seq_list = us_elem[0].split(' | ')#+[us_elem[1]]

        for us_m in us_seq_list:
#             print (f"{us_m} not in {target_seq}, {us_m not in target_seq}")
#             break

            if us_m not in target_seq:
                if us_m not in candidate_movies_dict:
                    candidate_movies_dict[us_m] = 0.
                candidate_movies_dict[us_m]+=us_w

#         assert 1==0

    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
#     print (candidate_pairs)
    candidate_items = [e[0] for e in candidate_pairs][:num_i]
    return candidate_items

# %% [markdown]
# ## Define item filtering

# %%
### item filtering
def soft_if_items(target_seq, num_i, total_i, item_matrix_sim, item_dict):
    candidate_movies_dict = {}
    for movie in target_seq:
#         print('ttt:',movie)
        sorted_is = sorted(list(enumerate(item_matrix_sim[item_dict[movie]])), key=lambda x: x[-1], reverse=True)[:num_i]
        for is_i, is_v in sorted_is:
            s_item = i_item_id_list[is_i]

            if s_item not in target_seq:
                if s_item not in candidate_movies_dict:
                    candidate_movies_dict[s_item] = 0.
                candidate_movies_dict[s_item] += is_v
#             print (item_id_list[is_i], candidate_movies_dict)
    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
#     print (candidate_pairs)
    candidate_items = [e[0] for e in candidate_pairs][:total_i]
#     print (candidate_items)
    return candidate_items

# %% [markdown]
# ## Select a subset of user sequences with high quality

# %%
'''
In order to economize, our initial step is to identify user sequences that exhibit a high probability of obtaining accurate predictions from GPT-3.5 based on their respective candidates.
Subsequently, we proceed to utilize the GPT-3.5 API to generate predictions for these promising user sequences.
'''
results_data_15 = []
length_limit = 8
num_u= 12
total_i = 19
count = 0
total = 0
cand_ids = []
for i in id_list[:1000]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')
    # User filtering
    candidate_items = sort_uf_items(seq_list, user_matrix_sim[i], num_u=num_u, num_i=total_i)

#     print (elem[-1], '-',seq_list[-1])

    if elem[-1] in candidate_items:
#         print ('HIT: 1')
        count += 1
        cand_ids.append(i)
    else:
        pass
#         print ('HIT: 0')
    total +=1
print (f'count/total:{count}/{total}={count*1.0/total}')
print ('-----------------\n')
# Out:
# count/total:170/943=0.18027571580063625
# -----------------

# %% [markdown]
# ## Define prompt templates

# %% [markdown]
# #### 2-step prompt

# %%
prompt_1 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: Please help me summarize the style and main actors of the movie I watched (Format: [no. a watched movie - style and main actors]).
Answer:
"""

prompt_2 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: Please help me summarize the style and main actors of the movie I watched (Format: [no. a watched movie - style and main actors]).
Answer: {}.
Step 2: Recommend 10 movies from the Candidate Set that have the similar style and same actors to the movies I've watched (Format: [no. a watched movie - a candidate movie])?.
Answer:
"""

# %%
count = 0
total = 0
results_data = []
for i in cand_ids[:]:#[:10] + cand_ids[49:57] + cand_ids[75:81]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')[::-1]

    candidate_items = sort_uf_items(seq_list, user_matrix_sim[i], num_u=num_u, num_i=total_i)
    random.shuffle(candidate_items)

    input_1 = prompt_1.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]))

    message_1 = [
          {"role": "system", "content": "You are a helpful movie recommendation expert."},
          {"role": "user", "content": input_1},
    ]

    try_nums = 5
    kk_flag = 1
    while try_nums:
        try:
            response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_1,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
            # response = openai.ChatCompletion.create(
            #           model="gpt-3.5-turbo",
            #           messages=message_1,
            #           temperature=1.2,
            #           max_tokens=512,
            #           top_p=1,
            #           n=5,
            #           frequency_penalty=-0.5,
            #           presence_penalty=0.5,
            #     )
            try_nums = 0
            kk_flag = 1
        except Exception as e:
            if 'exceeded your current quota' in str(e):

                # open_ai_keys_index +=1
                openai.api_key = open_ai_keys[open_ai_keys_index]
            time.sleep(1)
            try_nums = try_nums-1
            kk_flag = 0

    if kk_flag == 0:
        time.sleep(5)
        response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_1,
                      max_tokens=256,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
        # response = openai.ChatCompletion.create(
        #               model="gpt-3.5-turbo",
        #               messages=message_1,
        #               temperature=1.2,
        #               max_tokens=512,
        #               top_p=1,
        #               n=5,
        #               frequency_penalty=-0.5,
        #               presence_penalty=0.5,
        #         )

    predictions_1 = response["choices"][0]['text']
    # predictions_1 = response.choices[0].message.content


    input_2 = prompt_2.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]), predictions_1)
    message_2 = [
          {"role": "system", "content": "You are a helpful movie recommendation expert."},
          {"role": "user", "content": input_2},
    ]

    try_nums = 5
    kk_flag = 1
    while try_nums:
        try:
            response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_2,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
            # response = openai.ChatCompletion.create(
            #           model="gpt-3.5-turbo",
            #           messages=message_2,
            #           temperature=1.2,
            #           max_tokens=512,
            #           top_p=1,
            #           n=5,
            #           frequency_penalty=-0.5,
            #           presence_penalty=0.5,
            #     )
            try_nums = 0
            kk_flag = 1
        except Exception as e:
            if 'exceeded your current quota' in str(e):

                # open_ai_keys_index +=1
                openai.api_key = open_ai_keys[open_ai_keys_index]
            time.sleep(1)
            try_nums = try_nums-1
            kk_flag = 0

    if kk_flag == 0:
        time.sleep(5)
        response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_2,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
        # response = openai.ChatCompletion.create(
        #               model="gpt-3.5-turbo",
        #               messages=message_2,
        #               temperature=1.2,
        #               max_tokens=512,
        #               top_p=1,
        #               n=5,
        #               frequency_penalty=-0.5,
        #               presence_penalty=0.5,
        #         )

    predictions = response["choices"][0]['text']
    # predictions = response.choices[0].message.content


    hit_=0
    if elem[1] in predictions:
        count += 1
        hit_ = 1
    else:
        pass
    total +=1



    # print (f"input_1:{input_1}")
    # print (f"predictions_1:{predictions_1}\n")
    # print (f"input_2:{input_2}")
    # print (f"predictions_2:{predictions_2}\n")
    # print (f"input_3:{input_3}")
    print (f"GT:{elem[1]}")
    print (f"predictions:{predictions}")

    # print (f"GT:{elem[-1]}")
    print (f'PID:{i}; count/total:{count}/{total}={count*1.0/total}\n')
    result_json = {"PID": i,
                   "Input_1": input_1,
                   "Input_2": input_2,
                   "GT": elem[1],
                   "Predictions_1": predictions_1,
                   "Predictions": predictions,
                   'Hit': hit_,
                   'Count': count,
                   'Current_total':total,
                   'Hit@10':count*1.0/total}
    results_data.append(result_json)


#file_dir = f"/content/drive/My Drive/Final_Project/result/results_multi_prompting_len{length_limit}_numcand_{total_i}_seed{rseed}.json"
file_dir = f"/content/drive/My Drive/Courses/AIPI531/AIPI_Final_Project/Results/results_multi_prompting_len{length_limit}_numcand_{total_i}_seed{rseed}_w.o.Trick.json"
write_json(results_data, file_dir)
# Out:
# GT:Under Siege 2: Dark Territory
# predictions:1. Happy Gilmore - The Shadow (starring Alec Baldwin and John Lone).
# 2. Boomerang - Money Train (starring Wesley Snipes and Woody Harrelson).
# 3. Made in America - Clear and Present Danger (starring Whoopi Goldberg and Harrison Ford).
# 4. Grease 2 - First Knight (starring Sean Connery and Richard Gere).
# 5. Michael - Die Hard 2 (starring John Travolta and Bruce Willis).
# 6. City Slickers II: The Legend of Curly's Gold - Young Guns (starring Emilio Estevez and Kiefer Sutherland).
# 7. Beverly Hills Cop III - Under Siege 2: Dark Territory (starring Steven Seagal and Eric Bogosian).
# 8. Grumpier Old Men - Days of Thunder (starring Tom Cruise and Robert Duvall).
# PID:16; count/total:1/1=1.0
#
# GT:Speed
# predictions:1. The Maltese Falcon - Under Siege 2: Dark Territory
# 2. Con Air - True Lies
# 3. Romy and Michele's High School Reunion - Money Train
# 4. Anastasia - The Three Musketeers
# 5. Grosse Pointe Blank - Stargate
# 6. The Fifth Element - Batman Returns
# 7. Starship Troopers - Full Metal Jacket
# 8. Wild America - Days of Thunder
# 9. Batman Forever - Batman
# 10. Star Trek VI: The Undiscovered Country - Star Trek III: The Search for Spock
# PID:18; count/total:1/2=0.5
#
# GT:Congo
# predictions:1. The Omen - Screamers
# 2. The Believers - From Dusk Till Dawn
# 3. Bram Stoker's Dracula - Bride of Frankenstein
# 4. Body Snatchers - Alien
# 5. Cape Fear - The Game
# 6. Frisk - Psycho
# 7. The Howling - Evil Dead II
# 8. The Shining - The Silence of the Lambs
# PID:20; count/total:1/3=0.3333333333333333
#
# GT:Toy Story
# predictions:1. Face/Off - Eraser starring John Travolta and Arnold Schwarzenegger.
# 2. Return of the Jedi - Star Wars starring Mark Hamill, Harrison Ford, and Carrie Fisher.
# 3. A Close Shave - Willy Wonka and the Chocolate Factory starring Gene Wilder.
# 4. The Rock - Mission: Impossible starring Tom Cruise and Nicolas Cage.
# 5. Spawn - Kingpin starring Woody Harrelson and Randy Quaid.
# 6. Liar Liar - Jerry Maguire starring Tom Cruise and Renée Zellweger.
# 7. Air Force One - Ransom starring Mel Gibson and Gary Sinise.
# 8. Contact - Phenomenon starring John Travolta and Kyra Sedgwick.
# 9. The Birdcage - Private Parts starring Howard Stern and Robin Quivers.
# 10. Independence Day (ID4) - Twister starring Helen Hunt and Bill Paxton.
# PID:30; count/total:1/4=0.25
#
# GT:Volcano
# predictions:1. Anaconda - Excess Baggage
# 2. Everyone Says I Love You - Chasing Amy
# 3. Dumb & Dumber - The Game
# 4. The Abyss - The Rainmaker
# 5. Return of the Jedi - Star Trek: First Contact
# 6. Jurassic Park - Dante's Peak
# 7. My Best Friend's Wedding - Boogie Nights
# 8. George of the Jungle - Wag the Dog
# 9. Scream 2 - Scream
# 10. Air Force One - Seven Years in Tibet
# PID:32; count/total:1/5=0.2
#
# GT:Independence Day (ID4)
# predictions:1. George of the Jungle - Jackie Chan's First Strike.
# 2. Conspiracy Theory - Bound.
# 3. Dante's Peak - Broken Arrow.
# 4. The Saint - Face/Off.
# 5. Liar Liar - My Best Friend's Wedding.
# 6. Air Force One - Independence Day (ID4).
# 7. Scream - The Truth About Cats & Dogs.
# 8. Contact - Tin Cup.
# 9. Willy Wonka and the Chocolate Factory - Matilda.
# 10. Rumble in the Bronx - Welcome to the Dollhouse.
# PID:42; count/total:2/6=0.3333333333333333
#
# GT:The Rock
# predictions:1. Live Nude Girls - The First Wives Club
# 2. The Long Kiss Goodnight - Eraser
# 3. The Frighteners - The Rock
# 4. Daylight - Executive Decision
# 5. Heat - The River Wild
# 6. Broken Arrow - Twister
# 7. High School High - Men in Black
# 8. The Shawshank Redemption - Jerry Maguire
# 9. The Hunchback of Notre Dame - My Best Friend's Wedding
# 10. Fargo - Down Periscope
# PID:59; count/total:3/7=0.42857142857142855
#
# GT:L.A. Confidential
# predictions:1. Boot - The Long Kiss Goodnight starring Tom Cruise and Samuel L. Jackson.
# 2. Das - G.I. Jane starring Demi Moore and Viggo Mortensen.
# 3. M*A*S*H - The Bridge on the River Kwai starring Alec Guinness and Jack Hawkins.
# 4. The Sound of Music - Seven Years in Tibet starring Brad Pitt and David Thewlis.
# 5. One Flew Over the Cuckoo's Nest - The Rainmaker starring Matt Damon and Danny DeVito.
# 6. The Deer Hunter - The Game starring Michael Douglas and Sean Penn.
# 7. My Life as a Dog (Mitt liv som hund) - Chasing Amy starring Ben Affleck and Joey Lauren Adams.
# 8. Glengarry Glen Ross - L.A. Confidential starring Kevin Spacey and Russell Crowe.
# 9. Indiana Jones and the Last Crusade - Raiders of the Lost Ark starring Harrison Ford and Karen Allen.
# 10. The Full Monty - Amistad starring Morgan Freeman and Anthony Hopkins.
# PID:67; count/total:4/8=0.5
#
# GT:Tales from the Crypt Presents: Bordello of Blood
# predictions:1. Jaws - The Fog
# 2. Pulp Fiction - From Dusk Till Dawn
# 3. Aliens - The Abyss
# 4. Alien - Hellraiser: Bloodline
# 5. Alien 3 - The Prophecy
# 6. The Graduate - April Fool's Day
# 7. Citizen Kane - Nosferatu (Nosferatu, eine Symphonie des Grauens)
# 8. 2001: A Space Odyssey - The Lawnmower Man
# 9. The Believers
# 10. Tales from the Hood
# PID:96; count/total:4/9=0.4444444444444444
#
# GT:Conspiracy Theory
# predictions:1. Picture Perfect - Jerry Maguire.
# 2. The Devil's Own - G.I. Jane.
# 3. Murder at 1600 - Conspiracy Theory.
# 4. The Saint - The Edge.
# 5. Spawn - Star Wars.
# 6. Liar Liar - The Full Monty.
# 7. Scream - Rosewood.
# 8. Mother - Ulee's Gold.
# PID:101; count/total:5/10=0.5
#
# GT:As Good As It Gets
# 7. L.A. Confidential - Seven Years in Tibet starring Brad Pitt and David Thewlis.
# 8. The English Patient - Good Will Hunting starring Matt Damon and Robin Williams.
# 9. Kull the Conqueror - Rosewood starring Ving Rhames and Jon Voight.
# 10. Starship Troopers - Mimic starring Mira Sorvino and Jeremy Northam.
# PID:165; count/total:17/24=0.7083333333333334
#
# GT:The Rock
# predictions:1. Four Weddings and a Funeral - The Truth About Cats & Dogs
# 2. Sleepless in Seattle - Star Trek: First Contact
# 3. Groundhog Day - Multiplicity
# 4. The Brothers McMullen - The Saint
# 5. When Harry Met Sally... - Sabrina
# 6. Forget Paris - The Birdcage
# 7. My Fellow Americans - Executive Decision
# 8. Bye Bye, Love - Courage Under Fire
# 9. Twister - Mars Attacks!
# 10. Return of the Jedi - Mr. Holland's Opus
# PID:170; count/total:17/25=0.68
#
# GT:Cool Hand Luke
# predictions:1. M - The Manchurian Candidate
# 2. Top Hat - The Sound of Music
# 3. Ridicule - Vertigo
# 4. The Wizard of Oz - Annie Hall
# 5. Like Water For Chocolate - Cinema Paradiso
# 6. The Philadelphia Story - Raiders of the Lost Ark
# 7. The 39 Steps - The Silence of the Lambs
# 8. Shanghai Triad - The Godfather
# 9. The Graduate - Lawrence of Arabia
# 10. Apollo 13 - Rear Window
# PID:177; count/total:17/26=0.6538461538461539
#
# GT:Things to Do in Denver when You're Dead
# predictions:1. Lone Star - Heat
# 2. Down Periscope - Things to Do in Denver when You're Dead
# 3. Multiplicity - Executive Decision
# 4. Mission: Impossible - The Rock
# 5. Willy Wonka and the Chocolate Factory - Sleepers
# 6. Bound - The River Wild
# 7. Ransom - Tin Cup
# 8. Dead Man Walking - The Juror
# 9. Star Wars - Kingpin
# 10. The Nutty Professor - Sabrina
# PID:178; count/total:18/27=0.6666666666666666
#
# GT:Amadeus
# predictions:1. The 39 Steps - Liar Liar (starring Jim Carrey).
# 2. The Treasure of the Sierra Madre - The Fugitive (starring Harrison Ford).
# 3. 2001: A Space Odyssey - Star Wars (starring Mark Hamill).
# 4. The Bridge on the River Kwai - Apollo 13 (starring Tom Hanks).
# 5. Monty Python and the Holy Grail - A Fish Called Wanda (starring John Cleese).
# 6. Rear Window - The Graduate (starring Dustin Hoffman).
# 7. How to Make an American Quilt - Raising Arizona (starring Nicolas Cage).
# 8. The Devil's Own - Indiana Jones and the Last Crusade (starring Harrison Ford).
# 9. Amadeus (starring Tom Hulce).
# 10. Back to the Future (starring Michael J. Fox).
# PID:179; count/total:19/28=0.6785714285714286
#
# GT:One Flew Over the Cuckoo's Nest
# predictions:1. The Sting - Butch Cassidy and the Sundance Kid (Paul Newman and Robert Redford).
# 2. Rebel Without a Cause - Psycho (James Dean).
# 3. Rear Window - Vertigo (James Stewart and Grace Kelly).
# 4. The Silence of the Lambs - The Usual Suspects (Anthony Hopkins).
# 5. Fly Away Home - Back to the Future (Jeff Daniels).
# 6. Murder at 1600 - Blade Runner (Wesley Snipes).
# 7. Mother - Annie Hall (Albert Brooks).
# 8. Liar Liar - Toy Story (Jim Carrey).
# PID:181; count/total:19/29=0.6551724137931034
#
# GT:Alien
# 4. That Thing You Do! - Bullets Over Broadway
# 5. Phenomenon - Forrest Gump
# 6. Willy Wonka and the Chocolate Factory - Annie Hall
# 7. Mystery Science Theater 3000: The Movie - Sneakers
# 8. Fargo - Muriel's Wedding
# PID:227; count/total:24/36=0.6666666666666666
#
# GT:Clear and Present Danger
# predictions:1. The Godfather - The Usual Suspects
# 2. The Empire Strikes Back - Star Trek IV: The Voyage Home
# 3. The Jackal - True Romance
# 4. Bean - The Princess Bride
# 5. Critical Care - Clear and Present Danger
# 6. McHale's Navy - Rumble in the Bronx
# 7. Free Willy 3: The Rescue - The Rock
# 8. Spawn - Batman Returns
# 9. Top Gun
# 10. Independence Day (ID4)
# PID:231; count/total:25/37=0.6756756756756757
#
# GT:Sabrina
# predictions:1. The Truth About Cats & Dogs - Sabrina (Romantic comedy starring Uma Thurman and Harrison Ford).
# 2. The Thin Blue Line - Quiz Show (Drama starring Rob Morrow and John Turturro).
# 3. Bullets Over Broadway - Chasing Amy (Romantic comedy starring Ben Affleck and Joey Lauren Adams).
# 4. Amadeus - Evita (Musical drama starring Madonna and Antonio Banderas).
# 5. Fargo - Miller's Crossing (Crime drama starring Gabriel Byrne and Albert Finney).
# 6. Apocalypse Now - The Godfather: Part II (Crime drama starring Al Pacino and Robert De Niro).
# 7. The English Patient - The Princess Bride (Romantic adventure starring Cary Elwes and Robin Wright).
# 8. The Full Monty - The Graduate (Comedy drama starring Dustin Hoffman and Anne Bancroft).
# PID:233; count/total:26/38=0.6842105263157895
#
# GT:Star Trek VI: The Undiscovered Country
# predictions:1. The War Room - Get Shorty
# 2. The Piano - The Last of the Mohicans
# 3. Don Juan DeMarco - True Lies
# 4. Lawrence of Arabia - The Hunt for Red October
# 5. Top Gun - Mission: Impossible
# 6. Richard III - GoldenEye
# 7. The Nightmare Before Christmas - Army of Darkness
# 8. From Dusk Till Dawn - Die Hard: With a Vengeance
# PID:235; count/total:26/39=0.6666666666666666
#
# GT:Murder at 1600
# predictions:1. Lost Highway - Gattaca
# 2. Everyone Says I Love You - The Full Monty
# 3. Mother - Seven Years in Tibet
# 4. Love Jones - Murder at 1600
# 5. The Edge - The Devil's Advocate
# 6. Scream - The Game
# 7. The English Patient - L.A. Confidential
# 8. Conspiracy Theory - Starship Troopers
# 9. The Edge - Hoodlum
# 10. Scream - The Peacemaker
# PID:237; count/total:27/40=0.675
#
# GT:Raiders of the Lost Ark
# predictions:1. Fargo - Cool Hand Luke (starring Paul Newman and George Kennedy).
# 2. Aliens - Die Hard (starring Bruce Willis and Alan Rickman).
# 3. The Third Man - The Manchurian Candidate (starring Laurence Harvey and Frank Sinatra).
# 4. Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# 10. The Edge - Fly Away Home
# PID:328; count/total:35/52=0.6730769230769231
#
# GT:Chasing Amy
# predictions:1. Fargo - Donnie Brasco
# 2. Face/Off - Eraser
# 3. White Squall - Dead Man Walking
# 4. Grosse Pointe Blank - My Best Friend's Wedding
# 5. Citizen Ruth - Beavis and Butt-head Do America
# 6. Jerry Maguire - Welcome to the Dollhouse
# 7. Trainspotting - The City of Lost Children
# 8. Star Wars - The Nutty Professor
# 9. Time to Kill - Swingers
# 10. A - The Hunchback of Notre Dame
# PID:334; count/total:35/53=0.660377358490566
#
# GT:Shine
# predictions:1. Like Water For Chocolate (Como agua para chocolate) - The Double Life of Veronique, La (Double Vie de Véronique, La).
# 2. Trainspotting - Chasing Amy.
# 3. Delicatessen - The Cook the Thief His Wife & Her Lover.
# 4. Cinema Paradiso - Room with a View, A.
# 5. Eat Drink Man Woman - Raise the Red Lantern.
# 6. Emma - Four Weddings and a Funeral.
# 7. Wings of Desire - Shadowlands.
# 8. Jean de Florette - Muriel's Wedding.
# PID:337; count/total:35/54=0.6481481481481481
#
# GT:Village of the Damned
# predictions:1. Desperado - Terminal Velocity
# 2. Striking Distance - Die Hard: With a Vengeance
# 3. First Knight - Stargate
# 4. Alien 3 - Army of Darkness
# 5. Star Trek VI: The Undiscovered Country - Star Trek III: The Search for Spock
# 6. Star Trek III: The Search for Spock - Star Trek VI: The Undiscovered Country
# 7. Young Guns - Wolf
# 8. Conan the Barbarian - Demolition Man
# 9. Tales From the Crypt Presents: Demon Knight - Cape Fear
# 10. Terminal Velocity - True Lies
# PID:343; count/total:35/55=0.6363636363636364
#
# GT:G.I. Jane
# predictions:1. Evita - Desperate Measures (starring Antonio Banderas).
# 2. Picture Perfect - Boogie Nights (starring Jennifer Aniston).
# 3. Money Talks - The Saint (starring Chris Tucker).
# 4. Jungle2Jungle - George of the Jungle (starring Tim Allen).
# 5. Dante's Peak - The Rainmaker (starring Pierce Brosnan).
# 6. Mother - Ulee's Gold (starring Albert Brooks).
# 7. Scream - The Devil's Own (starring Neve Campbell).
# 8. Liar Liar - The Devil's Advocate (starring Jim Carrey).
# 9. Gattaca (starring Ethan Hawke).
# 10. G.I. Jane (starring Demi Moore).
# PID:346; count/total:36/56=0.6428571428571429
#
# GT:Apt Pupil
# predictions:1. Cop Land - The Game
# 2. Everyone Says I Love You - Wag the Dog
# 3. Boogie Nights - The Full Monty
# 4. Fly Away Home - The Rainmaker
# 5. Contact - Dante's Peak
# 6. Air Force One - Murder at 1600
# 7. The English Patient - The Sweet Hereafter
# 8. Ulee's Gold - In the Company of Men
# PID:352; count/total:36/57=0.631578947368421
#
# GT:Raising Arizona
# predictions:1. The Man Without a Face - Butch Cassidy and the Sundance Kid (starring Mel Gibson).
# 2. Raiders of the Lost Ark - Indiana Jones and the Last Crusade (starring Harrison Ford).
# 3. Apollo 13 - Speed (starring Tom Hanks).
# 4. Forrest Gump - This Is Spinal Tap (starring Tom Hanks).
# 5. Muriel's Wedding - Babe (starring Toni Collette).
# 6. Red Corner - Clockwork Orange (starring Richard Gere).
# 7. Conspiracy Theory - Return of the Jedi (starring Mel Gibson).
# 8. Air Force One - One Flew Over the Cuckoo's Nest (starring Harrison Ford).
# 9. Clerks - Raising Arizona (starring Jeff Bridges).
# 10. Fish Called Wanda - E.T. the Extra-Terrestrial (starring Henry Thomas).
# PID:354; count/total:37/58=0.6379310344827587
#
# GT:Sleepless in Seattle
# predictions:1. Up Close and Personal - Room with a View
# 2. Speed - The Mask
# 3. To Die For - Chasing Amy
# 4. What's Eating Gilbert Grape - I.Q.
# 5. Now and Then - Reality Bites
# 6. Nell - The Birdcage
# 7. The Firm - Dave
# 8. The Parent Trap - Grease
# 9. Star Wars - Toy Story
# 10. Indiana Jones and the Last Crusade - Home Alone
# PID:357; count/total:37/59=0.6271186440677966
#
# GT:Babe
# predictions:1. Much Ado About Nothing - Four Weddings and a Funeral
# 2. Hamlet - Room with a View
# 3. Shine - Benny & Joon
# 4. Smoke - Bullets Over Broadway
# 5. Braveheart - Dances with Wolves
# 6. Stand by Me - Some Kind of Wonderful
# 7. Margaret's Museum - The Graduate
# 8. Schindler's List - One Flew Over the Cuckoo's Nest
# 9. Field of Dreams
# 10. Pulp Fiction
# PID:362; count/total:37/60=0.6166666666666667
#
# GT:The Devil's Advocate
# predictions:1. Red Corner - The Devil's Advocate.
# 2. Eve's Bayou - Chasing Amy.
# 3. Air Force One - The Peacemaker.
# 4. Mrs. Brown (Her Majesty, Mrs. Brown) - G.I. Jane.
# 5. Ulee's Gold - Liar Liar.
# 6. The Full Monty - The Game.
# 7. Kolya - Contact.
# 8. The English Patient - The Rainmaker.
# 9. U Turn - Scream.
# 10. Dante's Peak - Tomorrow Never Dies.
# PID:366; count/total:38/61=0.6229508196721312
#
# GT:When Harry Met Sally...
# predictions:1. Dead Poets Society - Beauty and the Beast
# 2. The Professional - True Romance
# 3. The Client - Get Shorty
# 4. Batman Returns - Toy Story
# 5. Full Metal Jacket - Forrest Gump
# 6. Army of Darkness - Monty Python and the Holy Grail
# 7. Pump Up the Volume - Field of Dreams
# 8. A Grand Day Out - The Wizard of Oz
# 9. Star Wars - The Empire Strikes Back
# 10. Groundhog Day - When Harry Met Sally...
# PID:382; count/total:39/62=0.6290322580645161
#
# GT:Return of the Jedi
# predictions:1. Toy Story - Beavis and Butt-head Do America.
# 2. Bound - Face/Off.
# 3. Leaving Las Vegas - Mission: Impossible.
# 4. Welcome to the Dollhouse - Chasing Amy.
# 5. Trainspotting - 2 Days in the Valley.
# 6. The English Patient - Secrets & Lies.
# 7. The Godfather - Heat.
# 8. Scream - Twister.
# 9. Sabrina - Jerry Maguire.
# 10. Breaking the Waves - Twelve Monkeys.
# PID:387; count/total:39/63=0.6190476190476191
#
# GT:Cool Hand Luke
# predictions:1. Die Hard - Star Trek: The Wrath of Khan.
# 2. The Godfather: Part II - The Godfather.
# 3. Casablanca - The Maltese Falcon.
# 4. Manon of the Spring (Manon des sources) - Dances with Wolves.
# 5. The Shawshank Redemption - The Usual Suspects.
# 6. Cinema Paradiso - Back to the Future.
# 7. The Fugitive - Blade Runner.
# 8. The Great Escape - Cool Hand Luke.
# 9. Gone with the Wind - Psycho.
# 10. Star Wars - Alien.
# PID:389; count/total:40/64=0.625
#
# GT:Fargo
# predictions:1. The Celluloid Closet - Ulee's Gold (Peter Fonda).
# 2. Richard III - Face/Off (Ian McKellen).
# 3. Star Wars - Men in Black (Will Smith, Tommy Lee Jones).
# 4. The Convent - The Birdcage (Nathan Lane).
# 5. Primal Fear - Donnie Brasco (Al Pacino, Johnny Depp).
# 6. Leaving Las Vegas - Dead Man Walking (Nicolas Cage, Susan Sarandon).
# 7. Everyone Says I Love You - Emma (Gwyneth Paltrow).
# 8. The English Patient - The Crucible (Ralph Fiennes).
# 9. Toy Story - Swingers (Vince Vaughn).
# 10. Big Night - Il Postino (Massimo Troisi).
# PID:406; count/total:40/65=0.6153846153846154
#
# GT:The Big Lebowski
# predictions:1. The Daytrippers - The Wedding Singer
# 2. Dracula: Dead and Loving It - The Devil's Advocate
# 3. Sliver - The Game
# 4. Ace Ventura: When Nature Calls - In & Out
# 5. The Substitute - Air Force One
# 6. Judge Dredd - Ulee's Gold
# 7. Beverly Hills Cop III - Boogie Nights
# 8. Daylight - Red Corner
# PID:412; count/total:40/66=0.6060606060606061
#
# GT:Liar Liar
# predictions:1. Bean - The Full Monty
# 2. Rosewood - Cop Land
# 3. Incognito - The Devil's Advocate
# 4. Air Force One - The Edge
# 5. The Ice Storm - The Saint
# 6. Career Girls - Chasing Amy
# 7. L.A. Confidential - Mother
# 8. Gattaca - The Peacemaker
# 9. The Rainmaker
# 10. Liar Liar
# PID:414; count/total:41/67=0.6119402985074627
#
# GT:Raiders of the Lost Ark
# predictions:1. Walk in the Clouds - E.T. the Extra-Terrestrial.
# 2. A - The Fugitive.
# 3. Rob Roy - The Piano.
# 4. Pretty Woman - Grease.
# 5. Ghost - The Nightmare Before Christmas.
# 6. Dave - Mary Poppins.
# 7. Legends of the Fall - Raiders of the Lost Ark.
# 8. The Bridges of Madison County - The Princess Bride.
# 9. The American President - Jerry Maguire.
# 10. Cool Runnings - The Secret Garden.
# PID:419; count/total:42/68=0.6176470588235294
#
# GT:Jerry Maguire
# predictions:1. Dante's Peak - Independence Day (ID4)
# 2. I Know What You Did Last Summer - Scream
# 3. Crash - Leaving Las Vegas
# 4. Liar Liar - The Long Kiss Goodnight
# 5. Scream - I Know What You Did Last Summer
# 6. The Edge - Face/Off
# 7. The Game - The Saint
# 8. The Devil's Own - Mission: Impossible
# 9. Sense and Sensibility - Willy Wonka and the Chocolate Factory
# 10. Mr. Holland's Opus - Jerry Maguire
# PID:427; count/total:43/69=0.6231884057971014
#
# GT:Star Trek: First Contact
# predictions:1. Mighty Aphrodite - The Truth About Cats & Dogs
# 2. Toy Story - Willy Wonka and the Chocolate Factory
# 3. Return of the Jedi - Star Trek: First Contact
# 4. Rumble in the Bronx - Kingpin
# 5. Star Wars - Courage Under Fire
# 6. Mother - Grosse Pointe Blank
# 7. Liar Liar - Face/Off
# 8. Contact - Mission: Impossible
# PID:428; count/total:44/70=0.6285714285714286
#
# GT:Star Wars
# predictions:1. The Manchurian Candidate - The Usual Suspects
# 2. Full Metal Jacket - The Graduate
# 3. Harold and Maude - Annie Hall
# 4. Rear Window - Psycho
# 5. Reservoir Dogs - Pulp Fiction
# 6. Dead Man Walking - Fargo
# 7. Raising Arizona - Back to the Future
# 8. Apollo 13 - GoodFellas
# 9. The Silence of the Lambs - Primal Fear
# 10. Star Wars - Return of the Jedi
# PID:435; count/total:45/71=0.6338028169014085
#
# GT:George of the Jungle
# predictions:1. Starship Troopers - Gattaca
# 2. The Game - The Devil's Advocate
# 3. Contact - The Peacemaker
# 4. Bean - George of the Jungle
# 5. FairyTale: A True Story - The English Patient
# 6. Seven Years in Tibet - Rosewood
# 7. The Rainmaker - Conspiracy Theory
# 8. Scream - Alien: Resurrection
# PID:438; count/total:46/72=0.6388888888888888
#
# GT:Cop Land
# predictions:1. Seven Years in Tibet - Air Force One (starring Harrison Ford).
# 2. Scream - Liar Liar (starring Jim Carrey).
# 3. Starship Troopers - The Edge (starring Anthony Hopkins and Alec Baldwin).
# 4. The Ice Storm - The Game (starring Michael Douglas).
# 5. Ulee's Gold - Kolya (starring Zdeněk Svěrák).
# 6. Contact - Gattaca (starring Ethan Hawke).
# 7. Boogie Nights - The Devil's Advocate (starring Al Pacino and Keanu Reeves).
# 8. L.A. Confidential - Murder at 1600 (starring Wesley Snipes and Diane Lane).
# 9. Kiss the Girls (starring Morgan Freeman).
# 10. Rosewood (starring Ving Rhames).
# PID:441; count/total:46/73=0.6301369863013698
#
# GT:Dead Man Walking
# predictions:1. Ulee's Gold - Desperate Measures (starring Michael Keaton and Andy Garcia).
# 2. Evita - Hoodlum (starring Laurence Fishburne and Andy Garcia).
# 3. FairyTale: A True Story - Seven Years in Tibet (starring Brad Pitt and David Thewlis).
# 4. Kolya - The Game (starring Sean Penn and Michael Caine).
# 5. L.A. Confidential - The Devil's Advocate (starring Keanu Reeves, Al Pacino, and Kevin Spacey).
# 6. The Full Monty - Mrs. Brown (Her Majesty, Mrs. Brown) (starring Judi Dench and Billy Connolly).
# 7. Rosewood - Conspiracy Theory (starring Mel Gibson and Julia Roberts).
# 8. Air Force One - Star Wars (starring Harrison Ford and Mark Hamill).
# PID:443; count/total:46/74=0.6216216216216216
#
# GT:The Edge
# predictions:1. The Jackal - The Peacemaker
# 2. The English Patient - The Rainmaker
# 3. Air Force One - Tomorrow Never Dies
# 4. Alien: Resurrection - Apt Pupil
# 5. The Full Monty - Everyone Says I Love You
# 6. L.A. Confidential - Boogie Nights
# 7. Chasing Amy - George of the Jungle
# 8. Contact - The Devil's Advocate
# PID:466; count/total:46/75=0.6133333333333333
#
# GT:The Silence of the Lambs
# predictions:1. The Empire Strikes Back - Die Hard
# 2. Vertigo - The Maltese Falcon
# 3. Toy Story - E.T. the Extra-Terrestrial
# 4. The Day the Earth Stood Still - 2001: A Space Odyssey
# 5. The Godfather - The Sting
# 6. Star Wars - Terminator 2: Judgment Day
# 7. Lost Highway - The Fugitive
# 8. The English Patient - The Graduate
# 9. Schindler's List - The Shawshank Redemption
# 10. One Flew Over the Cuckoo's Nest - GoodFellas
# PID:471; count/total:46/76=0.6052631578947368
#
# GT:Batman Returns
# predictions:1. My Fair Lady - The Sword in the Stone
# 2. Star Trek VI: The Undiscovered Country - Star Trek III: The Search for Spock
# 3. The Hunt for Red October - Clear and Present Danger
# 4. Top Gun - True Lies
# 5. The Terminator - Escape from New York
# 6. Apollo 13 - Aliens
# 7. The Good, The Bad and The Ugly - Highlander
# 8. Miller's Crossing - Stand by Me
# 9. Die Hard: With a Vengeance - Speed
# 10. Batman Returns - Waterworld
# PID:473; count/total:47/77=0.6103896103896104
#
# GT:The Saint
# predictions:1. Money Talks - Desperate Measures
# 2. The English Patient - Chasing Amy
# 3. The Rainmaker - Mrs. Brown (Her Majesty, Mrs. Brown)
# 4. A Thousand Acres - The Devil's Advocate
# 5. A - U Turn
# 6. The Full Monty - Red Corner
# 7. Air Force One - Titanic
# 8. Seven Years in Tibet - G.I. Jane
# 9. Liar Liar - Shadow Conspiracy
# 10. The Game - Rosewood
# PID:479; count/total:47/78=0.6025641025641025
#
# GT:Braveheart
# predictions:1. Dead Poets Society - Much Ado About Nothing (Drama starring Robin Williams, Robert Sean Leonard, and Ethan Hawke).
# 2. Speed - Raising Arizona (Action/Comedy starring Keanu Reeves, Sandra Bullock, and Dennis Hopper).
# 3. Being There - The Wrong Trousers (Comedy/Animation starring Peter Sellers, Shirley MacLaine, and Melvyn Douglas).
# 4. Schindler's List - Amadeus (Drama/Historical starring Liam Neeson, Ben Kingsley, and Ralph Fiennes).
# 5. Groundhog Day - Four Weddings and a Funeral (Comedy starring Bill Murray, Andie MacDowell, and Chris Elliott).
# 6. Arsenic and Old Lace - Get Shorty (Comedy/Mystery starring Cary Grant, Priscilla Lane, and Raymond Massey).
# 7. Liar Liar - Dave (Comedy starring Jim Carrey, Maura Tierney, and Justin Cooper).
# 8. Air Force One - The Blues Brothers (Action/Comedy starring Harrison Ford, Gary Oldman, and Glenn Close).
# PID:498; count/total:47/79=0.5949367088607594
#
# GT:Dante's Peak
# predictions:1. Ulee's Gold - The Apostle (drama starring Robert Duvall)
# 2. Kolya - Boogie Nights (drama starring Mark Wahlberg)
# 3. Good Will Hunting - Apt Pupil (drama starring Brad Renfro and Ian McKellen)
# 4. Air Force One - Murder at 1600 (action-thriller starring Harrison Ford)
# 5. L.A. Confidential - In & Out (comedy-drama starring Kevin Spacey and Matt Dillon)
# 6. The English Patient - Evita (musical drama starring Madonna and Antonio Banderas)
# 7. Titanic - Rosewood (drama starring Ving Rhames and Jon Voight)
# 8. Gattaca - Seven Years in Tibet (drama starring Brad Pitt and David Thewlis)
# PID:500; count/total:47/80=0.5875
#
# GT:Jackie Brown
# predictions:1. Mad City - Air Force One (John Travolta and Harrison Ford).
# 2. Lost Highway - The Devil's Advocate (Bill Pullman and Keanu Reeves).
# 3. Kiss the Girls - The Devil's Own (Morgan Freeman and Brad Pitt).
# 4. Titanic - Evita (Leonardo DiCaprio and Madonna).
# 5. Cop Land - G.I. Jane (Sylvester Stallone and Demi Moore).
# 6. The Game - Liar Liar (Michael Douglas and Jim Carrey).
# 7. Scream - Bean (Neve Campbell and Rowan Atkinson).
# 8. Chasing Amy - In & Out (Ben Affleck and Kevin Kline).
# PID:501; count/total:47/81=0.5802469135802469
#
# GT:The Jackal
# predictions:1. Boogie Nights - Jackie Brown
# 2. Contact - Gattaca
# 3. Chasing Amy - Everyone Says I Love You
# 4. Titanic - Red Corner
# 5. Lost Highway - The Edge
# 6. The Game - The Jackal
# 7. The Devil's Advocate - The Apostle
# 8. The English Patient - The Full Monty
# 9. Alien: Resurrection
# 10. Wag the Dog
# PID:506; count/total:48/82=0.5853658536585366
#
# GT:Contact
# predictions:1. The Godfather - L.A. Confidential
# 2. Star Wars - Air Force One
# 3. Dead Man Walking - Ulee's Gold
# 4. Postino, Il - Big Night
# 5. A Close Shave - The Birdcage
# 6. Return of the Jedi - Men in Black
# 7. Beautiful Thing - Sense and Sensibility
# 8. The English Patient - Emma
# 9. Lone Star - Fargo
# 10. Twelve Monkeys - Cold Comfort Farm
# PID:510; count/total:48/83=0.5783132530120482
#
# GT:Courage Under Fire
# predictions:1. Heaven's Prisoners - The Long Kiss Goodnight
# 2. Broken Arrow - Executive Decision
# 3. The Rock - Face/Off
# 4. The Godfather - The Craft
# 5. Shine - Phenomenon
# 6. The Funeral - Courage Under Fire
# 7. Father of the Bride Part II - One Fine Day
# 8. Sabrina - Willy Wonka and the Chocolate Factory
# 9. Tin Cup
# 10. Dragonheart
# PID:513; count/total:49/84=0.5833333333333334
#
# GT:The First Wives Club
# predictions:1. Men in Black - The Rock
# 2. Phenomenon - The Nutty Professor
# 3. In & Out - The First Wives Club
# 4. Air Force One - Con Air
# 5. Liar Liar - Ransom
# 6. Anastasia - Toy Story
# 7. Contact - Twelve Monkeys
# 8. The English Patient - Sense and Sensibility
# 9. Grumpier Old Men - Volcano
# 10. Dragonheart - Mr. Holland's Opus
# PID:523; count/total:50/85=0.5882352941176471
#
# GT:The Sting
# predictions:1. Casablanca - The Godfather
# 2. Monty Python's Life of Brian - Fish Called Wanda
# 3. Searching for Bobby Fischer - Philadelphia
# 4. Eve's Bayou - Raising Arizona
# 5. Life Less Ordinary - The Graduate
# 6. A - Psycho
# 7. Event Horizon - Blade Runner
# 8. Ulee's Gold - Taxi Driver
# 9. The Full Monty - The Sting
# 10. Vertigo - The Empire Strikes Back
# PID:526; count/total:51/86=0.5930232558139535
#
# GT:Carrie
# predictions:1. The Silence of the Lambs - Stephen King's The Langoliers
# 2. Twelve Monkeys - From Dusk Till Dawn
# 3. Fargo - Serial Mom
# 4. Pulp Fiction - Natural Born Killers
# 5. Jaws - A
# 6. Alien - Alien 3
# 7. The Godfather - The Prophecy
# 8. Hoop Dreams - Hoop Dreams
# 9. Screamers - Nightmare on Elm Street
# 10. Nosferatu (Nosferatu, eine Symphonie des Grauens) - Bram Stoker's Dracula
# PID:528; count/total:51/87=0.5862068965517241
#
# GT:Scream
# predictions:1. Indiana Jones and the Last Crusade - The Fifth Element
# 6. Little Princess - Muriel's Wedding
# 7. Three Colors: Red - Sense and Sensibility
# 8. Rebecca - Four Weddings and a Funeral
# 9. Dances with Wolves
# 10. The Graduate
# PID:816; count/total:85/142=0.5985915492957746
#
# GT:The Killing Fields
# predictions:1. Little Princess - Roman Holiday (Drama, starring Audrey Hepburn and Gregory Peck).
# 2. A - The Godfather (Crime drama, starring Marlon Brando and Al Pacino).
# 3. The Graduate - Some Like It Hot (Comedy, starring Marilyn Monroe and Tony Curtis).
# 4. Manon of the Spring - The Killing Fields (Drama, starring Sam Waterston and Haing S. Ngor).
# 5. The Manchurian Candidate - The Godfather Part II (Crime drama, starring Al Pacino and Robert De Niro).
# 6. GoodFellas - Pulp Fiction (Crime drama, starring John Travolta and Samuel L. Jackson).
# 7. Raising Arizona - Fish Called Wanda (Comedy, starring John Cleese and Jamie Lee Curtis).
# 8. Butch Cassidy and the Sundance Kid - Braveheart (Historical drama, starring Mel Gibson and Sophie Marceau).
# 9. Jerry Maguire - Like Water For Chocolate (Romantic drama, starring Marco Leonardi and Lumi Cavazos).
# 10. The Empire Strikes Back - Lawrence of Arabia (Adventure drama, starring Peter O'Toole and Alec Guinness).
# PID:820; count/total:86/143=0.6013986013986014
#
# GT:Scream
# predictions:1. Air Force One - The Saint (Action/Thriller starring Val Kilmer).
# 2. The Full Monty - The Jackal (Action/Thriller starring Bruce Willis).
# 3. In & Out - Chasing Amy (Comedy starring Ben Affleck).
# 4. Good Will Hunting - Desperate Measures (Drama starring Andy Garcia and Michael Keaton).
# 5. The English Patient - The Edge (Drama starring Anthony Hopkins and Alec Baldwin).
# 6. As Good As It Gets - Cop Land (Drama starring Sylvester Stallone and Robert De Niro).
# 7. Wag the Dog - Murder at 1600 (Thriller starring Wesley Snipes and Diane Lane).
# 8. The Peacemaker - The Devil's Advocate (Thriller starring Al Pacino and Keanu Reeves).
# 9. Evita (Musical starring Madonna).
# 10. Titanic (Romance starring Leonardo DiCaprio and Kate Winslet).
# PID:827; count/total:86/144=0.5972222222222222
#
# GT:Mother
# predictions:1. Mrs. Brown (Her Majesty, Mrs. Brown) - The Wings of the Dove
# 2. Good Will Hunting - Chasing Amy
# 3. The Sweet Hereafter - The Rainmaker
# 4. The Tango Lesson - The Game
# 5. The Ice Storm - Conspiracy Theory
# 6. Titanic - In & Out
# 7. L.A. Confidential - The Devil's Advocate
# 8. Air Force One - Tomorrow Never Dies
# 9. The English Patient - Midnight in the Garden of Good and Evil
# 10. Amistad - Deconstructing Harry
# PID:828; count/total:86/145=0.593103448275862
#
# GT:Twelve Monkeys
# predictions:1. Seven Years in Tibet - Air Force One
# 2. In & Out - My Best Friend's Wedding
# 3. The Wings of the Dove - Mother
# 4. Everyone Says I Love You - Postino, Il
# 5. Kundun - Tin Cup
# 6. In the Company of Men - The Birdcage
# 7. Ulee's Gold - The Spitfire Grill
# 8. Boogie Nights - Evita
# 9. The Godfather
# 10. Twelve Monkeys
# PID:838; count/total:87/146=0.5958904109589042
#
# GT:Evita
# predictions:1. Alien: Resurrection - Spawn
# 2. Contact - The Devil's Advocate
# 3. Titanic - Evita
# 4. The English Patient - The Edge
# 5. L.A. Confidential - Midnight in the Garden of Good and Evil
# 6. The Game - The Devil's Own
# 7. Wag the Dog - The Full Monty
# 8. Good Will Hunting - Apt Pupil
# 9. In & Out - Kiss the Girls
# 10. Amistad - Murder at 1600
# PID:839; count/total:88/147=0.5986394557823129
#
# GT:Richard III
# predictions:1. The Horseman on the Roof - My Left Foot
# 2. The Double Life of Veronique - The Unbearable Lightness of Being
# 3. The Umbrellas of Cherbourg - Cinema Paradiso
# 4. Pather Panchali - Eat Drink Man Woman
# 5. Three Colors: White - Three Colors: Red
# 6. Manon of the Spring - Muriel's Wedding
# 7. Emma - Sense and Sensibility
# 8. Like Water For Chocolate - The Adventures of Priscilla, Queen of the Desert
# 9. The Piano - Raise the Red Lantern
# 10. Fargo - Three Colors: Blue
# PID:843; count/total:88/148=0.5945945945945946
#
# GT:Cop Land
# predictions:1. Jackie Brown - Rosewood
# 2. Scream 2 - Desperate Measures
# 3. Contact - The Devil's Advocate
# 4. L.A. Confidential - The Rainmaker
# 5. Apt Pupil - Wag the Dog
# 6. The Edge - Evita
# 7. The Apostle - Mother
# 8. The Game - Seven Years in Tibet
# 9. Mad City - Cop Land
# 10. Kiss the Girls - Good Will Hunting
# PID:845; count/total:89/149=0.5973154362416108
#
# GT:One Flew Over the Cuckoo's Nest
# predictions:1. Fried Green Tomatoes - Being There
# 2. Boot - Das
# 3. Das - Boot
# 4. The English Patient - The Graduate
# 5. The Fifth Element - Contact
# 6. Star Wars - The Empire Strikes Back
# 7. The Big Lebowski - Raising Arizona
# 8. Return of the Jedi - Indiana Jones and the Last Crusade
# 9. The Rainmaker - The Shawshank Redemption
# 10. The Rainmaker - Forrest Gump
# PID:847; count/total:89/150=0.5933333333333334
#
# GT:Jerry Maguire
# predictions:1. Event Horizon - The Long Kiss Goodnight (starring Laurence Fishburne and Samuel L. Jackson).
# 2. Spawn - Men in Black (starring Will Smith and Tommy Lee Jones).
# 3. As Good As It Gets - Jerry Maguire (starring Jack Nicholson and Cuba Gooding Jr.).
# 4. Kull the Conqueror - The Frighteners (starring Michael J. Fox and Trini Alvarado).
# 5. The Saint - The Hunt for Red October (starring Sean Connery and Alec Baldwin).
# 6. In & Out - Liar Liar (starring Jim Carrey and Maura Tierney).
# 7. Dante's Peak - Time to Kill (starring Matthew McConaughey and Sandra Bullock).
# 8. G.I. Jane - Conspiracy Theory (starring Mel Gibson and Julia Roberts).
# 9. Beavis and Butt-head Do America (starring Mike Judge and Bruce Willis).
# 10. Sleepers (starring Robert De Niro and Brad Pitt).
# PID:859; count/total:90/151=0.5960264900662252
#
# GT:Jackie Brown
# predictions:1. Gattaca - The Edge
# 2. Amistad - The Devil's Advocate
# 3. Chasing Amy - Boogie Nights
# 4. The Peacemaker - The Saint
# 5. Tomorrow Never Dies - The Game
# 6. Eve's Bayou - Jackie Brown
# 7. Career Girls - The Full Monty
# 8. The Apostle - Red Corner
# 9. Murder at 1600 - Kiss the Girls
# 10. In & Out - George of the Jungle
# 7. Apt Pupil - In & Out (starring Ian McKellen and Kevin Kline).
# 8. Kiss the Girls - Cop Land (starring Morgan Freeman and Robert De Niro).
# 9. Dante's Peak - Ulee's Gold (starring Peter Fonda and Patricia Richardson).
# 10. Volcano - Tomorrow Never Dies (starring Pierce Brosnan and Jonathan Pryce).
# PID:874; count/total:93/157=0.5923566878980892
#
# GT:Waterworld
# predictions:1. GoodFellas - The Terminator
# 2. The Good, The Bad and The Ugly - The Last of the Mohicans
# 3. Ben-Hur - True Lies
# 4. Conan the Barbarian - Broken Arrow
# 5. Butch Cassidy and the Sundance Kid - Money Train
# 6. Under Siege - Last Action Hero
# 7. The Magnificent Seven - Jurassic Park
# 8. Highlander - Independence Day (ID4)
# 9. The Hunt for Red October - Star Trek: The Wrath of Khan
# 10. Waterworld - Star Trek IV: The Voyage Home
# PID:875; count/total:94/158=0.5949367088607594
#
# GT:Event Horizon
# predictions:1. Rocket Man - George of the Jungle
# 2. Hoodlum - L.A. Confidential
# 3. Chasing Amy - The Game
# 4. Air Force One - The Devil's Advocate
# 5. The Wedding Singer - The Full Monty
# 6. Titanic - The English Patient
# 7. Scream - Event Horizon
# 8. The Edge - Fly Away Home
# 9. Bean - In & Out
# 10. Desperate Measures - Kiss the Girls
# PID:882; count/total:95/159=0.5974842767295597
#
# GT:Sense and Sensibility
# predictions:1. Amistad - L.A. Confidential
# 2. Good Will Hunting - Chasing Amy
# 3. Apt Pupil - The Devil's Advocate
# 4. Titanic - Contact
# 5. Air Force One - Murder at 1600
# 6. Seven Years in Tibet - The Edge
# 7. The English Patient - Sense and Sensibility
# 8. The Full Monty - Mrs. Brown (Her Majesty, Mrs. Brown)
# 9. Volcano - Dante's Peak
# 10. Kiss the Girls - Jackie Brown
# PID:883; count/total:96/160=0.6
#
# GT:Mars Attacks!
# predictions:1. The Celluloid Closet - Secrets & Lies
# 2. Sense and Sensibility - The First Wives Club
# 3. Toy Story - Men in Black
# 4. Fargo - Scream
# 5. Dead Man Walking - Courage Under Fire
# 6. Good Will Hunting - Jerry Maguire
# 7. Titanic - Sabrina
# 8. Contact - The Rock
# PID:884; count/total:96/161=0.5962732919254659
#
# GT:Lone Star
# predictions:1. Ridicule - The People vs. Larry Flynt
# 2. Jane Eyre - Emma
# 3. Sense and Sensibility - Secrets & Lies
# 4. Twelve Monkeys - Boot
# 5. Ransom - Face/Off
# 6. Chasing Amy - Jerry Maguire
# 7. The English Patient - The Rock
# 8. Air Force One - Courage Under Fire
# 9. The Frighteners - Men in Black
# 10. Return of the Jedi - Lone Star
# PID:886; count/total:97/162=0.5987654320987654
#
# GT:Star Trek: First Contact
# predictions:1. Terminator 2: Judgment Day - Broken Arrow
# 2. Star Trek: The Motion Picture - Star Trek: First Contact
# 3. Star Trek Generations - Alien
# 4. Star Trek V: The Final Frontier - In the Line of Fire
# 5. Star Trek VI: The Undiscovered Country - True Lies
# 6. Star Trek: The Wrath of Khan - Top Gun
# 7. Star Trek III: The Search for Spock - Clear and Present Danger
#
# GT:Good Will Hunting
# predictions:1. Bean - The Full Monty
# 2. Tomorrow Never Dies - The Devil's Advocate
# 3. Liar Liar - George of the Jungle
# 4. The Peacemaker - Cop Land
# 5. Scream - The Edge
# 6. The Rainmaker - Good Will Hunting
# 7. Jackie Brown - L.A. Confidential
# 8. Seven Years in Tibet - Contact
# 9. Amistad - Evita
# 10. Dante's Peak - G.I. Jane
# PID:942; count/total:101/170=0.5941176470588235

# %% [markdown]
# #### 2-step prompt (With modified hint)

# %%
prompt_1 = """
You are an expert in movie recommendation.
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: Please help me summarize the style and main actors of the movie I watched (Format: [no. a watched movie - style and main actors]).
Answer:
"""

prompt_2 = """
You are an expert in movie recommendation.
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: Please help me summarize the style and main actors of the movie I watched (Format: [no. a watched movie - style and main actors]).
Answer: {}.
Step 2: Please think step by step, and recommend 10 movies from the Candidate Set that have the similar style and same actors to the movies I've watched (Format: [no. a watched movie - a candidate movie])?.
Answer:
"""

# %%
count = 0
total = 0
results_data = []
for i in cand_ids[:]:#[:10] + cand_ids[49:57] + cand_ids[75:81]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')[::-1]

    candidate_items = sort_uf_items(seq_list, user_matrix_sim[i], num_u=num_u, num_i=total_i)
    random.shuffle(candidate_items)

    input_1 = prompt_1.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]))

    message_1 = [
          {"role": "system", "content": "You are a helpful movie recommendation expert."},
          {"role": "user", "content": input_1},
    ]

    try_nums = 5
    kk_flag = 1
    while try_nums:
        try:
            response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_1,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
            # response = openai.ChatCompletion.create(
            #           model="gpt-3.5-turbo",
            #           messages=message_1,
            #           temperature=1.2,
            #           max_tokens=512,
            #           top_p=1,
            #           n=5,
            #           frequency_penalty=-0.5,
            #           presence_penalty=0.5,
            #     )
            try_nums = 0
            kk_flag = 1
        except Exception as e:
            if 'exceeded your current quota' in str(e):

                # open_ai_keys_index +=1
                openai.api_key = open_ai_keys[open_ai_keys_index]
            time.sleep(1)
            try_nums = try_nums-1
            kk_flag = 0

    if kk_flag == 0:
        time.sleep(5)
        response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_1,
                      max_tokens=256,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
        # response = openai.ChatCompletion.create(
        #               model="gpt-3.5-turbo",
        #               messages=message_1,
        #               temperature=1.2,
        #               max_tokens=512,
        #               top_p=1,
        #               n=5,
        #               frequency_penalty=-0.5,
        #               presence_penalty=0.5,
        #         )

    predictions_1 = response["choices"][0]['text']
    # predictions_1 = response.choices[0].message.content


    input_2 = prompt_2.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]), predictions_1)
    message_2 = [
          {"role": "system", "content": "You are a helpful movie recommendation expert."},
          {"role": "user", "content": input_2},
    ]

    try_nums = 5
    kk_flag = 1
    while try_nums:
        try:
            response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_2,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
            # response = openai.ChatCompletion.create(
            #           model="gpt-3.5-turbo",
            #           messages=message_2,
            #           temperature=1.2,
            #           max_tokens=512,
            #           top_p=1,
            #           n=5,
            #           frequency_penalty=-0.5,
            #           presence_penalty=0.5,
            #     )
            try_nums = 0
            kk_flag = 1
        except Exception as e:
            if 'exceeded your current quota' in str(e):

                # open_ai_keys_index +=1
                openai.api_key = open_ai_keys[open_ai_keys_index]
            time.sleep(1)
            try_nums = try_nums-1
            kk_flag = 0

    if kk_flag == 0:
        time.sleep(5)
        response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_2,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
        # response = openai.ChatCompletion.create(
        #               model="gpt-3.5-turbo",
        #               messages=message_2,
        #               temperature=1.2,
        #               max_tokens=512,
        #               top_p=1,
        #               n=5,
        #               frequency_penalty=-0.5,
        #               presence_penalty=0.5,
        #         )

    predictions = response["choices"][0]['text']
    # predictions = response.choices[0].message.content


    hit_=0
    if elem[1] in predictions:
        count += 1
        hit_ = 1
    else:
        pass
    total +=1



    # print (f"input_1:{input_1}")
    # print (f"predictions_1:{predictions_1}\n")
    # print (f"input_2:{input_2}")
    # print (f"predictions_2:{predictions_2}\n")
    # print (f"input_3:{input_3}")
    print (f"GT:{elem[1]}")
    print (f"predictions:{predictions}")

    # print (f"GT:{elem[-1]}")
    print (f'PID:{i}; count/total:{count}/{total}={count*1.0/total}\n')
    result_json = {"PID": i,
                   "Input_1": input_1,
                   "Input_2": input_2,
                   "GT": elem[1],
                   "Predictions_1": predictions_1,
                   "Predictions": predictions,
                   'Hit': hit_,
                   'Count': count,
                   'Current_total':total,
                   'Hit@10':count*1.0/total}
    results_data.append(result_json)


#file_dir = f"/content/drive/My Drive/Final_Project/result/results_multi_prompting_len{length_limit}_numcand_{total_i}_seed{rseed}.json"
file_dir = f"/content/drive/My Drive/Courses/AIPI531/AIPI_Final_Project/Results/results_multi_prompting_len{length_limit}_numcand_{total_i}_seed{rseed}_w.Trick.json"
write_json(results_data, file_dir)
# Out:
# GT:Under Siege 2: Dark Territory
# predictions:1. Happy Gilmore - Clear and Present Danger (starring Harrison Ford).
# 2. Boomerang - Star Trek IV: The Voyage Home (starring Eddie Murphy).
# 3. Made in America - Highlander (starring Christopher Lambert).
# 4. Grease 2 - Young Guns (starring Emilio Estevez).
# 5. Michael - Days of Thunder (starring Tom Cruise).
# 6. City Slickers II: The Legend of Curly's Gold - Under Siege 2: Dark Territory (starring Steven Seagal).
# 7. Beverly Hills Cop III - Independence Day (ID4) (starring Will Smith).
# 8. Grumpier Old Men - The Crow (starring Brandon Lee).
# 9. First Knight (starring Sean Connery).
# 10. Stargate (starring Kurt Russell).
# PID:16; count/total:1/1=1.0
#
# GT:Speed
# predictions:1. The Maltese Falcon - True Lies (Humphrey Bogart and Mary Astor).
# 2. Con Air - Batman Forever (Nicolas Cage and John Cusack).
# 3. Romy and Michele's High School Reunion - Natural Born Killers (Lisa Kudrow and Mira Sorvino).
# 4. Anastasia - Batman Returns (John Cusack and Meg Ryan).
# 5. Grosse Pointe Blank - Full Metal Jacket (John Cusack and Minnie Driver).
# 6. The Fifth Element - Star Trek III: The Search for Spock (Bruce Willis and Milla Jovovich).
# 7. Starship Troopers - Star Trek VI: The Undiscovered Country (Casper Van Dien and Denise Richards).
# 8. Wild America - The Crow (Jonathan Taylor Thomas and Devon Sawa).
# 9. The Maltese Falcon - Under Siege (Humphrey Bogart and Mary Astor).
# 10. Con Air - Money Train (Nicolas Cage and John Cusack).
# PID:18; count/total:1/2=0.5
#
# GT:Congo
# predictions:1. The Omen - Psycho
# 2. The Believers - The Game
# 3. Bram Stoker's Dracula - Bride of Frankenstein
# 4. Body Snatchers - Aliens
# 5. Cape Fear - Fargo
# 6. Frisk - Evil Dead II
# 7. The Howling - Scream
# 8. The Shining - Twelve Monkeys
# 9. Screamers - From Dusk Till Dawn
# 10. Carrie - Jaws
# PID:20; count/total:1/3=0.3333333333333333
#
# GT:Toy Story
# predictions:1. Face/Off - The Saint, Ransom, Eraser, Rumble in the Bronx.
# 2. Return of the Jedi - Star Wars.
# 3. Close Shave - Willy Wonka and the Chocolate Factory.
# 4. A - Conspiracy Theory, Phenomenon.
# 5. The Rock - The People vs. Larry Flynt, Private Parts, Jerry Maguire.
# 6. Spawn - Mission: Impossible, Fargo, Twister, Kingpin.
# 7. Liar Liar - The Birdcage.
# 8. Air Force One - Independence Day (ID4).
# 9. Contact - Toy Story.
# PID:30; count/total:2/4=0.5
#
# GT:Volcano
# predictions:1. Anaconda - Excess Baggage
# 2. Everyone Says I Love You - Chasing Amy
# 3. Dumb & Dumber - The Game
# 4. The Abyss - Starship Troopers
# 5. Return of the Jedi - Star Trek: First Contact
# 6. Jurassic Park - Volcano
# 7. My Best Friend's Wedding - Seven Years in Tibet
# 8. George of the Jungle - Toy Story
# 9. Boogie Nights
# 10. Air Force One
# PID:32; count/total:3/5=0.6
#
# GT:Independence Day (ID4)
# predictions:1. George of the Jungle - Sabrina (Comedy, starring Harrison Ford).
# 2. Conspiracy Theory - Face/Off (Thriller, starring John Travolta and Nicolas Cage).
# 3. Dante's Peak - Independence Day (ID4) (Action/Adventure, starring Will Smith).
# 4. The Saint - Bound (Action/Thriller, starring Gina Gershon and Jennifer Tilly).
# 5. Liar Liar - My Best Friend's Wedding (Comedy, starring Julia Roberts).
# 6. Air Force One - Broken Arrow (Action/Thriller, starring John Travolta).
# 7. Scream - The Truth About Cats & Dogs (Romantic Comedy, starring Uma Thurman).
# 8. Contact - Tin Cup (Romantic Comedy, starring Kevin Costner).
# 9. Willy Wonka and the Chocolate Factory (Fantasy, starring Gene Wilder).
# 10. Jackie Chan's First Strike (Action/Adventure, starring Jackie Chan).
# PID:42; count/total:4/6=0.6666666666666666
#
# GT:The Rock
# predictions:1. Live Nude Girls - The First Wives Club
# 2. The Long Kiss Goodnight - Executive Decision
# 3. The Frighteners - The Craft
# 4. Daylight - Twister
# 5. Heat - Eraser
# 6. Broken Arrow - The Rock
# 7. High School High - My Best Friend's Wedding
# 8. The Shawshank Redemption - Mr. Holland's Opus
# PID:59; count/total:5/7=0.7142857142857143
#
# GT:L.A. Confidential
# predictions:1. Boot - The Long Kiss Goodnight
# 2. Das - The Silence of the Lambs
# 3. M*A*S*H - The Bridge on the River Kwai
# 4. The Sound of Music - The Full Monty
# 5. One Flew Over the Cuckoo's Nest - The People vs. Larry Flynt
# 6. The Deer Hunter - The Rainmaker
# 7. My Life as a Dog (Mitt liv som hund) - Chasing Amy
# 8. Glengarry Glen Ross - G.I. Jane
# 9. Indiana Jones and the Last Crusade - Raiders of the Lost Ark
# 10. Seven Years in Tibet - Amistad
# PID:67; count/total:5/8=0.625
#
# GT:Tales from the Crypt Presents: Bordello of Blood
# predictions:1. Jaws - The Howling
# 2. Pulp Fiction - From Dusk Till Dawn
# 3. Aliens - The Abyss
# 6. The Grifters - The Sting
# 7. The Usual Suspects - Pulp Fiction
# 8. Jurassic Park - The Truth About Cats & Dogs
# 9. The Fugitive - Dances with Wolves
# 10. When Harry Met Sally... - Forrest Gump
# PID:141; count/total:10/17=0.5882352941176471
#
# GT:Michael
# predictions:1. Grumpier Old Men - The Birdcage
# 2. Eddie - That Thing You Do!
# 3. Multiplicity - Ransom
# 4. Father of the Bride Part II - The First Wives Club
# 5. Twister - Executive Decision
# 6. One Fine Day - Up Close and Personal
# 7. The Fan - Absolute Power
# 8. Rumble in the Bronx - Toy Story
# 9. Twelve Monkeys - Fargo
# 10. James and the Giant Peach - Sabrina
# PID:148; count/total:10/18=0.5555555555555556
#
# GT:Everyone Says I Love You
# predictions:1. The Peacemaker - The Devil's Advocate starring George Clooney and Nicole Kidman.
# 2. Seven Years in Tibet - Evita starring Brad Pitt and David Thewlis.
# 3. Indian Summer - Everyone Says I Love You starring Alan Arkin, Diane Lane, and Bill Paxton.
# 4. Fly Away Home - George of the Jungle starring Jeff Daniels and Anna Paquin.
# 5. Kolya - Excess Baggage starring Zdenek Sverák and Andrej Chalimon.
# 6. Ulee's Gold - Liar Liar starring Peter Fonda and Patricia Richardson.
# 7. Contact - Conspiracy Theory starring Jodie Foster and Matthew McConaughey.
# 8. Air Force One - Murder at 1600 starring Harrison Ford and Gary Oldman.
# 9. Dante's Peak - Volcano starring Pierce Brosnan and Anne Heche.
# 10. Kiss the Girls - The Devil's Own starring Morgan Freeman and Brad Pitt.
# PID:155; count/total:11/19=0.5789473684210527
#
# GT:Fantasia
# predictions:1. Don Juan DeMarco - The Godfather
# 2. Nina Takes a Lover - Get Shorty
# 3. The Last of the Mohicans - The Magnificent Seven
# 4. Monty Python's Life of Brian - Monty Python and the Holy Grail
# 5. Four Weddings and a Funeral - Mary Poppins
# 6. Indiana Jones and the Last Crusade - The Hunt for Red October, True Lies
# 7. Brazil - Twelve Monkeys
# 8. Pulp Fiction - Under Siege
# 9. Glory - The Rock
# 10. The Fugitive - Die Hard: With a Vengeance
# PID:156; count/total:11/20=0.55
#
# GT:City Hall
# predictions:1. Star Wars - Return of the Jedi, The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One.
# 2. Like Water For Chocolate (Como agua para chocolate) - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat.
# 3. This Is Spinal Tap - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat, Donnie Brasco.
# 4. The Prophecy - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat, Donnie Brasco, Liar Liar.
# 5. Gandhi - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat, Donnie Brasco, Liar Liar, City Hall.
# 6. The African Queen - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat, Donnie Brasco, Liar Liar, City Hall, Twelve Monkeys.
# 7. To Kill a Mockingbird - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat, Donnie Brasco, Liar Liar, City Hall, Twelve Monkeys, Twister.
# 8. Streetcar Named Desire - The Long Kiss Goodnight, Toy Story, Willy Wonka and the Chocolate Factory, The Rock, Mars Attacks!, Eraser, Ransom, Independence Day (ID4), Air Force One, Heat, Donnie Brasco, Liar Liar, City Hall, Twelve Monkeys, Twister, The Saint.
# 9. A. - The Long Kiss Goodnight, Toy Story, Willy Won
# PID:158; count/total:12/21=0.5714285714285714
#
# GT:Unforgiven
# predictions:1. The Blues Brothers - Strictly Ballroom (starring Paul Mercurio and Tara Morice).
# 3. Ridicule - Cinema Paradiso
# 4. The Wizard of Oz - Annie Hall
# 5. Like Water For Chocolate - The Graduate
# 6. The Philadelphia Story - Rear Window
# 7. The 39 Steps - Vertigo
# 8. Shanghai Triad - Chinatown
# 9. Lawrence of Arabia - Raiders of the Lost Ark
# 10. The Empire Strikes Back - Star Wars
# PID:177; count/total:15/26=0.5769230769230769
#
# GT:Things to Do in Denver when You're Dead
# predictions:1. Lone Star - Heat
# 2. Down Periscope - Things to Do in Denver When You're Dead
# 3. Multiplicity - The Nutty Professor
# 4. Mission: Impossible - Executive Decision
# 5. Willy Wonka and the Chocolate Factory - Sabrina
# 6. Bound - The Craft
# 7. Ransom - The Juror
# 8. Dead Man Walking - Sleepers
# 9. Star Wars - Return of the Jedi
# 10. Star Trek: First Contact - Dragonheart
# PID:178; count/total:15/27=0.5555555555555556
#
# GT:Amadeus
# predictions:1. The 39 Steps - Liar Liar (starring Jim Carrey).
# 2. The Treasure of the Sierra Madre - The Empire Strikes Back (starring Harrison Ford).
# 3. 2001: A Space Odyssey - Blade Runner (starring Harrison Ford).
# 4. The Bridge on the River Kwai - The Fugitive (starring Harrison Ford).
# 5. Monty Python and the Holy Grail - Raising Arizona (starring Nicolas Cage).
# 6. Rear Window - It's a Wonderful Life (starring James Stewart).
# 7. How to Make an American Quilt - Amadeus (starring F. Murray Abraham).
# 8. The Devil's Own - Apollo 13 (starring Tom Hanks).
# 9. Alien (starring Sigourney Weaver).
# 10. Dances with Wolves (starring Kevin Costner).
# PID:179; count/total:16/28=0.5714285714285714
#
# GT:One Flew Over the Cuckoo's Nest
# predictions:1. The Sting - Butch Cassidy and the Sundance Kid (both starring Paul Newman and Robert Redford).
# 2. Rebel Without a Cause - Vertigo (both starring James Dean and Sal Mineo).
# 3. Rear Window - Psycho (both starring James Stewart and Grace Kelly).
# 4. The Silence of the Lambs - Alien (both starring Jodie Foster and Anthony Hopkins).
# 5. Fly Away Home - Toy Story (both starring Anna Paquin and Jeff Daniels).
# 6. Murder at 1600 - The Usual Suspects (both starring Wesley Snipes and Diane Lane).
# 7. Mother - Annie Hall (both starring Albert Brooks and Debbie Reynolds).
# 8. Liar Liar - Back to the Future (both starring Jim Carrey and Maura Tierney).
# 9. The Terminator - Raiders of the Lost Ark (both starring Arnold Schwarzenegger).
# 10. The Shawshank Redemption - Gandhi (both starring Morgan Freeman).
# PID:181; count/total:16/29=0.5517241379310345
#
# GT:Alien
# predictions:1. The Empire Strikes Back - Return of the Jedi
# 2. The Right Stuff - Field of Dreams
# 3. The Aristocats - Grease
# 4. The Hudsucker Proxy - The Blues Brothers
# 5. Tombstone - Raiders of the Lost Ark
# 6. Miracle on 34th Street - Somewhere in Time
# 7. The Birds - Alien
# 8. Ace Ventura: Pet Detective - Indiana Jones and the Last Crusade
# 9. The Silence of the Lambs - Bram Stoker's Dracula
# 10. Blade Runner - Monty Python and the Holy Grail
# PID:184; count/total:17/30=0.5666666666666667
#
# GT:Pulp Fiction
# predictions:1. Patton - The Right Stuff
# 2. North by Northwest - The Fugitive
# 3. Star Wars - Return of the Jedi
# 7. Don Juan DeMarco - Much Ado About Nothing
# 8. Shadowlands - Jurassic Park
# 9. Willy Wonka and the Chocolate Factory - Return of the Jedi
# 10. Dances with Wolves - Four Weddings and a Funeral
# PID:223; count/total:19/35=0.5428571428571428
#
# GT:Heathers
# predictions:1. Very Brady Sequel - Muriel's Wedding
# 2. A - The Silence of the Lambs
# 3. Joe's Apartment - Heathers
# 4. Jack - Bullets Over Broadway
# 5. That Thing You Do! - Maverick
# 6. Phenomenon - Sneakers
# 7. Willy Wonka and the Chocolate Factory - The Return of the Pink Panther
# 8. Mystery Science Theater 3000: The Movie - The Truth About Cats & Dogs
# 9. Fargo - While You Were Sleeping
# 10. Forrest Gump - Jurassic Park
# PID:227; count/total:20/36=0.5555555555555556
#
# GT:Clear and Present Danger
# predictions:1. The Godfather - The Usual Suspects
# 2. The Empire Strikes Back - Star Trek IV: The Voyage Home
# 3. The Jackal - The Rock
# 4. Bean - The Princess Bride
# 5. Critical Care - Clear and Present Danger
# 6. McHale's Navy - True Romance
# 7. Free Willy 3: The Rescue - Rumble in the Bronx
# 8. Spawn - Batman Returns
# 9. Top Gun
# 10. Independence Day (ID4)
# PID:231; count/total:21/37=0.5675675675675675
#
# GT:Sabrina
# predictions:1. The Truth About Cats & Dogs - Raising Arizona (Romantic comedy starring Nicolas Cage and Holly Hunter).
# 2. The Thin Blue Line - Miller's Crossing (Crime drama starring Gabriel Byrne and Albert Finney).
# 3. Bullets Over Broadway - Chasing Amy (Romantic comedy starring Ben Affleck and Joey Lauren Adams).
# 4. Amadeus - Evita (Musical drama starring Madonna and Antonio Banderas).
# 5. Fargo - The Silence of the Lambs (Crime drama starring Jodie Foster and Anthony Hopkins).
# 6. Apocalypse Now - 2001: A Space Odyssey (Sci-fi drama starring Keir Dullea and Gary Lockwood).
# 7. The English Patient - Quiz Show (Drama starring Ralph Fiennes and John Turturro).
# 8. The Full Monty - The Princess Bride (Comedy drama starring Cary Elwes and Robin Wright).
# PID:233; count/total:21/38=0.5526315789473685
#
# GT:Star Trek VI: The Undiscovered Country
# predictions:1. The War Room - Clear and Present Danger
# 2. The Piano - Ghost
# 3. Don Juan DeMarco - True Lies
# 4. Lawrence of Arabia - The Last of the Mohicans
# 5. Top Gun - Die Hard 2
# 6. Richard III - Blade Runner
# 7. The Nightmare Before Christmas - Army of Darkness
# 8. From Dusk Till Dawn - Star Trek III: The Search for Spock
# 9. Under Siege - Die Hard: With a Vengeance
# 10. Independence Day (ID4) - The Hunt for Red October
# PID:235; count/total:21/39=0.5384615384615384
#
# GT:Murder at 1600
# predictions:1. Lost Highway - The Devil's Advocate
# 2. Everyone Says I Love You - In & Out
# 3. Mother - Chasing Amy
# 4. Love Jones - Soul Food
# 5. The Edge - The Game
# 6. Scream - The Peacemaker
# 7. The English Patient - Seven Years in Tibet
# 8. Conspiracy Theory - Gattaca
# 9. Evita - Fly Away Home
# 10. Murder at 1600 - Hoodlum
# PID:237; count/total:22/40=0.55
#
# GT:Raiders of the Lost Ark
# predictions:1. Fargo - The Sting
# 2. Aliens - Terminator 2: Judgment Day
# 3. The Third Man - Chinatown
# 4. Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bom
# 10. Tales From the Crypt Presents: Demon Knight - The Lawnmower Man
# PID:343; count/total:31/55=0.5636363636363636
#
# GT:G.I. Jane
# predictions:1. Evita - The Devil's Advocate (starring Al Pacino and Keanu Reeves).
# 2. Picture Perfect - Boogie Nights (starring Mark Wahlberg and Julianne Moore).
# 3. Money Talks - The Jackal (starring Bruce Willis and Richard Gere).
# 4. Jungle2Jungle - George of the Jungle (starring Brendan Fraser and Leslie Mann).
# 5. Dante's Peak - Seven Years in Tibet (starring Brad Pitt and David Thewlis).
# 6. Mother - Desperate Measures (starring Andy Garcia and Michael Keaton).
# 7. Scream - Kiss the Girls (starring Morgan Freeman and Ashley Judd).
# 8. Liar Liar - Murder at 1600 (starring Wesley Snipes and Diane Lane).
# 9. Alien: Resurrection (starring Sigourney Weaver and Winona Ryder).
# 10. The Saint (starring Val Kilmer and Elisabeth Shue).
# PID:346; count/total:31/56=0.5535714285714286
#
# GT:Apt Pupil
# predictions:1. Cop Land - The Game
# 2. Everyone Says I Love You - The Sweet Hereafter
# 3. Boogie Nights - The Full Monty
# 4. Fly Away Home - The Rainmaker
# 5. Contact - In & Out
# 6. Air Force One - Wag the Dog
# 7. The English Patient - The Apostle
# 8. Ulee's Gold - Good Will Hunting
# 9. Dante's Peak - G.I. Jane
# 10. Amistad - Liar Liar
# PID:352; count/total:31/57=0.543859649122807
#
# GT:Raising Arizona
# predictions:1. The Man Without a Face - Clerks (Comedy starring Brian O'Halloran and Jeff Anderson).
# 2. Raiders of the Lost Ark - Indiana Jones and the Last Crusade (Action-adventure starring Harrison Ford).
# 3. Apollo 13 - Stand by Me (Drama starring Wil Wheaton and River Phoenix).
# 4. Forrest Gump - Babe (Comedy-drama starring James Cromwell and Magda Szubanski).
# 5. Muriel's Wedding - Four Weddings and a Funeral (Romantic comedy starring Hugh Grant).
# 6. Red Corner - A Few Good Men (Drama starring Tom Cruise and Jack Nicholson).
# 7. Conspiracy Theory - The Princess Bride (Fantasy-comedy starring Cary Elwes and Robin Wright).
# 8. Air Force One - Speed (Action-thriller starring Keanu Reeves and Sandra Bullock).
# 9. This Is Spinal Tap - A Clockwork Orange (Drama starring Malcolm McDowell).
# 10. Raising Arizona - One Flew Over the Cuckoo's Nest (Drama starring Jack Nicholson).
# PID:354; count/total:32/58=0.5517241379310345
#
# GT:Sleepless in Seattle
# predictions:1. Up Close and Personal - The Birdcage
# 2. Speed - The Mask
# 3. To Die For - Chasing Amy
# 4. What's Eating Gilbert Grape - Room with a View
# 5. Now and Then - Grease
# 6. Nell - I.Q.
# 7. The Firm - The Net
# 8. The Parent Trap - Toy Story
# 9. The Sound of Music
# 10. Home Alone
# PID:357; count/total:32/59=0.5423728813559322
#
# GT:Babe
# predictions:1. Much Ado About Nothing - Four Weddings and a Funeral
# 2. Hamlet - Room with a View
# 3. Shine - Bullets Over Broadway
# 4. Smoke - Philadelphia
# 5. Braveheart - Dances with Wolves
# 6. Stand by Me - Some Kind of Wonderful
# 7. Margaret's Museum - Benny & Joon
# 8. Schindler's List - Searching for Bobby Fischer
# PID:362; count/total:32/60=0.5333333333333333
#
# GT:The Devil's Advocate
# predictions:1. Red Corner - The Devil's Advocate
# 2. Eve's Bayou - Chasing Amy
# 3. Air Force One - The Peacemaker
# 4. Mrs. Brown (Her Majesty, Mrs. Brown) - The Edge
# 5. Ulee's Gold - Liar Liar
# 6. The Full Monty - In & Out
# 7. Kolya - Gattaca
# 8. The English Patient - Contact
# 9. Kiss the Girls - Scream
# 10. Conspiracy Theory - Tomorrow Never Dies
# PID:366; count/total:33/61=0.5409836065573771
#
# GT:When Harry Met Sally...
# predictions:1. Dead Poets Society - The Princess Bride
# 2. The Professional - True Romance
# 3. The Client - Get Shorty
# 4. Batman Returns - Toy Story
# 5. Full Metal Jacket - Amadeus
# 6. Army of Darkness - Monty Python and the Holy Grail
# 7. Pump Up the Volume - Field of Dreams
# 8. A Grand Day Out - The Wizard of Oz
# 9. Return of the Jedi - The Empire Strikes Back
# 10. To Kill a Mockingbird - Schindler's List
# PID:382; count/total:33/62=0.532258064516129
#
# GT:Return of the Jedi
# predictions:1. Toy Story - Beavis and Butt-head Do America.
# 2. Bound - Face/Off.
# 3. Leaving Las Vegas - Chasing Amy.
# 4. Welcome to the Dollhouse - Secrets & Lies.
# 5. Trainspotting - Twelve Monkeys.
# 6. The English Patient - Heat.
# 7. The Godfather - Mission: Impossible.
# 8. Scream - Men in Black.
# 9. Twister - Return of the Jedi.
# 10. Independence Day (ID4) - Jerry Maguire.
# PID:387; count/total:34/63=0.5396825396825397
#
# GT:Cool Hand Luke
# predictions:1. Die Hard - Star Wars
# 2. The Godfather: Part II - The Godfather
# 3. Casablanca - The Maltese Falcon
# 4. Manon of the Spring (Manon des sources) - To Kill a Mockingbird
# 5. The Shawshank Redemption - Cool Hand Luke
# 6. Cinema Paradiso - Back to the Future
# 7. The Fugitive - Highlander
# 8. The Great Escape - The Usual Suspects
# 9. Psycho - The Silence of the Lambs
# 10. Dances with Wolves - Gandhi
# PID:389; count/total:35/64=0.546875
#
# GT:Fargo
# predictions:1. The Celluloid Closet - The Birdcage (starring Robin Williams and Nathan Lane).
# 2. Richard III - Dead Man Walking (starring Sean Penn and Susan Sarandon).
# 3. Star Wars - Face/Off (starring John Travolta and Nicolas Cage).
# 4. The Convent - Twelve Monkeys (starring Bruce Willis and Brad Pitt).
# 5. Primal Fear - Donnie Brasco (starring Al Pacino and Johnny Depp).
# 6. Leaving Las Vegas - Ulee's Gold (starring Peter Fonda).
# 7. Everyone Says I Love You - The Godfather (starring Marlon Brando and Al Pacino).
# 8. The English Patient - Antonia's Line (starring Willeke van Ammelrooy).
# 9. Swingers (starring Vince Vaughn and Jon Favreau).
# 10. Big Night (starring Tony Shalhoub and Stanley Tucci).
# PID:406; count/total:35/65=0.5384615384615384
#
# GT:The Big Lebowski
# predictions:1. The Daytrippers - The Wedding Singer
# 2. Dracula: Dead and Loving It - The Devil's Advocate
# 3. Sliver - The Big Lebowski
# 4. Ace Ventura: When Nature Calls - The Game
# 6. Titanic - The English Patient
# 7. L.A. Confidential - In the Company of Men
# 8. Air Force One - Tomorrow Never Dies
# 9. Mother - Deconstructing Harry
# 10. In & Out - Midnight in the Garden of Good and Evil
# PID:828; count/total:81/145=0.5586206896551724
#
# GT:Twelve Monkeys
# predictions:1. Seven Years in Tibet - Twelve Monkeys
# 2. In & Out - My Best Friend's Wedding
# 3. The Wings of the Dove - Restoration
# 4. Everyone Says I Love You - The Birdcage
# 5. Kundun - Postino, Il
# 6. In the Company of Men - Jerry Maguire
# 7. Ulee's Gold - Dead Man Walking
# 8. Boogie Nights - Face/Off
# 9. Tin Cup - Air Force One
# 10. Trainspotting - Donnie Brasco
# PID:838; count/total:82/146=0.5616438356164384
#
# GT:Evita
# predictions:1. Alien: Resurrection - Scream
# 2. Contact - The Devil's Advocate
# 3. Titanic - Evita
# 4. The English Patient - The Edge
# 5. L.A. Confidential - In & Out
# 6. The Game - Liar Liar
# 7. Wag the Dog - The Full Monty
# 8. Good Will Hunting - Murder at 1600
# 9. Dante's Peak
# 10. The Rainmaker
# PID:839; count/total:83/147=0.564625850340136
#
# GT:Richard III
# predictions:1. The Horseman on the Roof - My Life as a Dog
# 2. The Double Life of Veronique - The Adventures of Priscilla, Queen of the Desert
# 3. The Umbrellas of Cherbourg - Muriel's Wedding
# 4. Pather Panchali - Three Colors: Blue
# 5. Three Colors: White - Cinema Paradiso
# 6. Manon of the Spring - Eat Drink Man Woman
# 7. Emma - Raise the Red Lantern
# 8. Like Water For Chocolate - Richard III
# 9. The Piano - Clockwork Orange
# 10. Fargo - Il Postino
# PID:843; count/total:84/148=0.5675675675675675
#
# GT:Cop Land
# predictions:1. Jackie Brown - Kiss the Girls
# 2. Scream 2 - Mad City
# 3. Contact - Seven Years in Tibet
# 4. L.A. Confidential - Rosewood
# 5. Apt Pupil - The Devil's Own
# 6. The Edge - Ulee's Gold
# 7. The Apostle - The Saint
# 8. The Game - The Devil's Advocate
# 9. Dante's Peak - Mother
# 10. Murder at 1600 - Cop Land
# PID:845; count/total:85/149=0.5704697986577181
#
# GT:One Flew Over the Cuckoo's Nest
# predictions:1. Fried Green Tomatoes - Being There
# 2. Boot - The Empire Strikes Back
# 3. Das - Psycho
# 4. The English Patient - Sabrina
# 5. The Fifth Element - Star Trek: First Contact
# 6. Star Wars - Raiders of the Lost Ark
# 7. The Big Lebowski - Raising Arizona
# 8. Return of the Jedi - Indiana Jones and the Last Crusade
# 9. The Rainmaker - The Godfather
# 10. Vertigo - Pulp Fiction
# PID:847; count/total:85/150=0.5666666666666667
#
# GT:Jerry Maguire
# predictions:1. Event Horizon - The Frighteners
# 2. Spawn - The Long Kiss Goodnight
# 3. As Good As It Gets - Liar Liar
# 4. Kull the Conqueror - The Silence of the Lambs
# 5. The Saint - The Fugitive
# 6. In & Out - Beavis and Butt-head Do America
# 7. Dante's Peak - Willy Wonka and the Chocolate Factory
# 8. G.I. Jane - GoodFellas
# 9. The Hunt for Red October - Chasing Amy
# 10. Sleepers - Jerry Maguire
# 4. Deconstructing Harry - Boogie Nights (starring Mark Wahlberg, Julianne Moore, and Burt Reynolds).
# 5. Kundun - Seven Years in Tibet (starring Brad Pitt, David Thewlis, and BD Wong).
# 6. Everyone Says I Love You - As Good As It Gets (starring Jack Nicholson, Helen Hunt, and Greg Kinnear).
# 7. Good Will Hunting - Red Corner (starring Richard Gere, Bai Ling, and Bradley Whitford).
# 8. Apt Pupil - Desperate Measures (starring Michael Keaton, Andy Garcia, and Marcia Gay Harden).
# PID:872; count/total:88/155=0.567741935483871
#
# GT:Titanic
# predictions:1. G.I. Jane - The Saint (starring Val Kilmer)
# 2. The Devil's Own - The Peacemaker (starring George Clooney)
# 3. Gattaca - Ulee's Gold (starring Peter Fonda)
# 4. Air Force One - The Jackal (starring Bruce Willis)
# 5. Conspiracy Theory - Liar Liar (starring Jim Carrey)
# 6. In & Out - Mother (starring Albert Brooks)
# 7. The Edge - The Rainmaker (starring Matt Damon)
# 8. Boogie Nights - Evita (starring Madonna)
# PID:873; count/total:88/156=0.5641025641025641
#
# GT:The Saint
# predictions:1. Ayn Rand: A Sense of Life - The Apostle
# 2. The English Patient - Evita
# 3. The Rainmaker - Desperate Measures
# 4. Good Will Hunting - Boogie Nights
# 5. Titanic - The Peacemaker
# 6. The Edge - Mad City
# 7. Wag the Dog - The Saint
# 8. Apt Pupil - In & Out
# 9. Dante's Peak - Ulee's Gold
# 10. The Full Monty - Kiss the Girls
# PID:874; count/total:89/157=0.5668789808917197
#
# GT:Waterworld
# predictions:1. GoodFellas - True Lies
# 2. The Good, The Bad and The Ugly - The Last of the Mohicans
# 3. Ben-Hur - The Hunt for Red October
# 4. Conan the Barbarian - Aliens
# 5. Butch Cassidy and the Sundance Kid - Bad Boys
# 6. Under Siege - Money Train
# 7. The Magnificent Seven - Broken Arrow
# 8. Highlander - Star Trek IV: The Voyage Home
# 9. Jurassic Park - Independence Day (ID4)
# 10. Clear and Present Danger - Mission: Impossible
# PID:875; count/total:89/158=0.5632911392405063
#
# GT:Event Horizon
# predictions:1. Rocket Man - Bean (Rowan Atkinson and Peter MacNicol).
# 2. Hoodlum - The Game (Michael Douglas and Sean Penn).
# 3. Chasing Amy - Liar Liar (Jim Carrey and Maura Tierney).
# 4. Air Force One - The Devil's Advocate (Harrison Ford and Gary Oldman).
# 5. The Wedding Singer - In & Out (Adam Sandler and Drew Barrymore).
# 6. Titanic - The English Patient (Leonardo DiCaprio and Kate Winslet).
# 7. Scream - Event Horizon (Laurence Fishburne and Sam Neill).
# 8. The Edge - The Full Monty (Anthony Hopkins and Alec Baldwin).
# 9. Jackie Brown - Cop Land (Robert De Niro and Sylvester Stallone).
# 10. Fly Away Home - George of the Jungle (Jeff Daniels and Anna Paquin).
# PID:882; count/total:90/159=0.5660377358490566
#
# GT:Sense and Sensibility
# predictions:1. Amistad - The Edge
# 2. Good Will Hunting - Chasing Amy
# 3. Apt Pupil - Scream
# 4. Titanic - Sense and Sensibility
# 5. Air Force One - The Devil's Own
# 6. Seven Years in Tibet - Contact
