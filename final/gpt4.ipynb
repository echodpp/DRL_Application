# %% [markdown]
# <a href="https://colab.research.google.com/github/echodpp/DRL_Application/blob/main/final/gpt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2023.11.17)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Installing collected packages: openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed openai-0.28.0

# %%
import time
import numpy as np
import json
import openai
import random
import argparse

# %%
rseed = 114514
random.seed(rseed)

# %%
def read_json(file):
    with open(file) as f:
        return json.load(f)

def write_json(data, file):
    with open(file, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=2)

data_ml_100k = read_json("/content/drive/MyDrive/Final_Project/ml_100k.json")

# %%
print (data_ml_100k[0][0])
print (data_ml_100k[0][1])
print (len(data_ml_100k))
# Out:
# My Best Friend's Wedding | The English Patient | Face/Off | Psycho | The Princess Bride | Kids | Kids in the Hall: Brain Candy | Scream | The Craft | The Rock | The Shining | Mission: Impossible | Reality Bites | Aliens | Indiana Jones and the Last Crusade | One Flew Over the Cuckoo's Nest | In the Name of the Father | Return of the Jedi | The Silence of the Lambs | The Usual Suspects | Dances with Wolves | Monty Python's Life of Brian | Monty Python and the Holy Grail | The Full Monty | Clockwork Orange, A | Apocalypse Now | Trainspotting | The Doors | Mr. Holland's Opus | Independence Day (ID4) | Liar Liar | Titanic | What's Eating Gilbert Grape | The Saint | Donnie Brasco | The Empire Strikes Back | Beautiful Girls | Mars Attacks! | Broken Arrow | Amistad | The Long Kiss Goodnight | French Kiss | The Maltese Falcon | Dazed and Confused | Strange Days
# Starship Troopers
# 943

# %%
open_ai_keys = ['']
openai.api_base = "https://api.openai.com/v1"
open_ai_keys_index = 0
openai.api_key = open_ai_keys[open_ai_keys_index]

# %%
u_item_dict = {}
u_item_p = 0
for elem in data_ml_100k:
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in u_item_dict:
            u_item_dict[movie] = u_item_p
            u_item_p +=1
print (len(u_item_dict))
u_item_len = len(u_item_dict)

user_list = []
for i, elem in  enumerate(data_ml_100k):
    item_hot_list = [0 for ii in range(u_item_len)]
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        item_pos = u_item_dict[movie]
        item_hot_list[item_pos] = 1
    user_list.append(item_hot_list)
user_matrix = np.array(user_list)
user_matrix_sim = np.dot(user_matrix, user_matrix.transpose())


pop_dict = {}
for elem in data_ml_100k:
    # elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in pop_dict:
              pop_dict[movie] = 0
        pop_dict[movie] += 1



i_item_dict = {}
i_item_id_list = []
i_item_user_dict = {}
i_item_p = 0
for i, elem in  enumerate(data_ml_100k):
    seq_list = elem[0].split(' | ')
    for movie in seq_list:
        if movie not in i_item_user_dict:
            item_hot_list = [0. for ii in range(len(data_ml_100k))]
            i_item_user_dict[movie] = item_hot_list
            i_item_dict[movie] = i_item_p
            i_item_id_list.append(movie)
            i_item_p+=1
#         item_pos = item_dict[movie]
        i_item_user_dict[movie][i] += 1
#     user_list.append(item_hot_list)
i_item_s_list = []
for item in i_item_id_list:
    i_item_s_list.append(i_item_user_dict[item])
#     print (sum(item_user_dict[item]))
item_matrix = np.array(i_item_s_list)
item_matrix_sim = np.dot(item_matrix, item_matrix.transpose())

id_list =list(range(0,len(data_ml_100k)))
# Out:
# 1493

# %%
### user filtering
def sort_uf_items(target_seq, us, num_u, num_i):

    candidate_movies_dict = {}
    sorted_us = sorted(list(enumerate(us)), key=lambda x: x[-1], reverse=True)[:num_u]
    dvd = sum([e[-1] for e in sorted_us])
    for us_i, us_v in sorted_us:
        us_w = us_v * 1.0/dvd
#         print (us_i)
        us_elem = data_ml_100k[us_i]
#         print (us_elem[0])
#         assert 1==0
        us_seq_list = us_elem[0].split(' | ')#+[us_elem[1]]

        for us_m in us_seq_list:
#             print (f"{us_m} not in {target_seq}, {us_m not in target_seq}")
#             break

            if us_m not in target_seq:
                if us_m not in candidate_movies_dict:
                    candidate_movies_dict[us_m] = 0.
                candidate_movies_dict[us_m]+=us_w

#         assert 1==0

    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
#     print (candidate_pairs)
    candidate_items = [e[0] for e in candidate_pairs][:num_i]
    return candidate_items

# %%
### item filtering
def soft_if_items(target_seq, num_i, total_i, item_matrix_sim, item_dict):
    candidate_movies_dict = {}
    for movie in target_seq:
#         print('ttt:',movie)
        sorted_is = sorted(list(enumerate(item_matrix_sim[item_dict[movie]])), key=lambda x: x[-1], reverse=True)[:num_i]
        for is_i, is_v in sorted_is:
            s_item = i_item_id_list[is_i]

            if s_item not in target_seq:
                if s_item not in candidate_movies_dict:
                    candidate_movies_dict[s_item] = 0.
                candidate_movies_dict[s_item] += is_v
#             print (item_id_list[is_i], candidate_movies_dict)
    candidate_pairs = list(sorted(candidate_movies_dict.items(), key=lambda x:x[-1], reverse=True))
#     print (candidate_pairs)
    candidate_items = [e[0] for e in candidate_pairs][:total_i]
#     print (candidate_items)
    return candidate_items

# %%
'''
In order to economize, our initial step is to identify user sequences that exhibit a high probability of obtaining accurate predictions from GPT-3.5 based on their respective candidates.
Subsequently, we proceed to utilize the GPT-3.5 API to generate predictions for these promising user sequences.
'''
results_data_15 = []
length_limit = 8
num_u= 12
total_i = 19
count = 0
total = 0
cand_ids = []
for i in id_list[:1000]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')

    candidate_items = sort_uf_items(seq_list, user_matrix_sim[i], num_u=num_u, num_i=total_i)

#     print (elem[-1], '-',seq_list[-1])

    if elem[-1] in candidate_items:
#         print ('HIT: 1')
        count += 1
        cand_ids.append(i)
    else:
        pass
#         print ('HIT: 0')
    total +=1
print (f'count/total:{count}/{total}={count*1.0/total}')
print ('-----------------\n')
# Out:
# count/total:170/943=0.18027571580063625
# -----------------

# %%
# message = [
#     {"role": "system", "content": "You are a helpful movie recommendation expert."},
#     {"role": "user", "content": in_text},
# ]

temp_1 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)?
Answer:
"""

temp_2 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)?
Answer: {}.
Step 2: Selecting the most featured movies from the watched movies according to my preferences (Format: [no. a watched movie.]).
Answer:
"""

temp_3 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: What features are most important to me when selecting movies (Summarize my preferences briefly)?
Answer: {}.
Step 2: Selecting the most featured movies (at most 5 movies) from the watched movies according to my preferences in descending order (Format: [no. a watched movie.]).
Answer: {}.
Step 3: Can you recommend 10 movies from the Candidate Set similar to the selected movies I've watched (Format: [no. a watched movie - a candidate movie])?.
Answer:
"""

prompt_1 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: Please help me summarize the style and main actors of the movie I watched (Format: [no. a watched movie - style and main actors]).
Answer:
"""

prompt_2 = """
Candidate Set (candidate movies): {}.
The movies I have watched (watched movies): {}.
Step 1: Please help me summarize the style and main actors of the movie I watched (Format: [no. a watched movie - style and main actors]).
Answer: {}.
Step 2: Please think step by step, and recommend 10 movies from the Candidate Set that have the similar style and same actors to the movies I've watched (Format: [no. a watched movie - a candidate movie])?.
Answer:
"""

# %%
count = 0
total = 0
results_data = []
for i in cand_ids[:]:#[:10] + cand_ids[49:57] + cand_ids[75:81]:
    elem = data_ml_100k[i]
    seq_list = elem[0].split(' | ')[::-1]

    candidate_items = sort_uf_items(seq_list, user_matrix_sim[i], num_u=num_u, num_i=total_i)
    random.shuffle(candidate_items)

    # input_1 = temp_1.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]))
    input_1 = prompt_1.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]))


    message_1 = [
          {"role": "system", "content": "You are a helpful movie recommendation expert."},
          {"role": "user", "content": input_1},
    ]

    try_nums = 5
    kk_flag = 1
    while try_nums:
        try:
            response = openai.Completion.create(
                      model="gpt-4",
                      prompt=input_1,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
            try_nums = 0
            kk_flag = 1
        except Exception as e:
            if 'exceeded your current quota' in str(e):

                # open_ai_keys_index +=1
                openai.api_key = open_ai_keys[open_ai_keys_index]
            time.sleep(1)
            try_nums = try_nums-1
            kk_flag = 0

    if kk_flag == 0:
        time.sleep(5)
        response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_1,
                      max_tokens=256,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )

    predictions_1 = response["choices"][0]['text']
    # predictions_1 = response.choices[0].message.content


    input_2 = prompt_2.format(', '.join(candidate_items), ', '.join(seq_list[-length_limit:]), predictions_1)
    message_2 = [
          {"role": "system", "content": "You are a helpful movie recommendation expert."},
          {"role": "user", "content": input_2},
    ]

    try_nums = 5
    kk_flag = 1
    while try_nums:
        try:
            response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_2,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )
            try_nums = 0
            kk_flag = 1
        except Exception as e:
            if 'exceeded your current quota' in str(e):

                # open_ai_keys_index +=1
                openai.api_key = open_ai_keys[open_ai_keys_index]
            time.sleep(1)
            try_nums = try_nums-1
            kk_flag = 0

    if kk_flag == 0:
        time.sleep(5)
        response = openai.Completion.create(
                      model="text-davinci-003",
                      prompt=input_2,
                      max_tokens=512,
                      temperature=0,
                      top_p=1,
                      frequency_penalty=0,
                      presence_penalty=0,
                      n = 1,
                  )

    predictions = response["choices"][0]['text']
    # predictions = response.choices[0].message.content


    hit_=0
    if elem[1] in predictions:
        count += 1
        hit_ = 1
    else:
        pass
    total +=1

    print (f"GT:{elem[1]}")
    print (f"predictions:{predictions}")

    # print (f"GT:{elem[-1]}")
    print (f'PID:{i}; count/total:{count}/{total}={count*1.0/total}\n')
    result_json = {"PID": i,
                   "Input_1": input_1,
                   "Input_2": input_2,
                   "GT": elem[1],
                   "Predictions_1": predictions_1,
                   "Predictions": predictions,
                   'Hit': hit_,
                   'Count': count,
                   'Current_total':total,
                   'Hit@10':count*1.0/total}
    results_data.append(result_json)


file_dir = f"/content/drive/MyDrive/Final_Project/result/results_multi_prompting_len{length_limit}_numcand_{total_i}_seed{rseed}.json"
write_json(results_data, file_dir)
# Out:
# GT:Under Siege 2: Dark Territory
# predictions:1. Happy Gilmore - Money Train (starring Adam Sandler).
# 2. Boomerang - The Shadow (starring Eddie Murphy).
# 3. Made in America - Die Hard 2 (starring Whoopi Goldberg and Ted Danson).
# 4. Grease 2 - First Knight (starring Michelle Pfeiffer).
# 5. Michael - Terminal Velocity (starring John Travolta).
# 6. City Slickers II: The Legend of Curly's Gold - Young Guns (starring Billy Crystal and Daniel Stern).
# 7. Beverly Hills Cop III - Under Siege 2: Dark Territory (starring Eddie Murphy).
# 8. Grumpier Old Men - Batman Forever (starring Jack Lemmon and Walter Matthau).
# PID:16; count/total:1/1=1.0
#
# GT:Speed
# predictions:1. The Maltese Falcon - Star Trek VI: The Undiscovered Country
# 2. Con Air - True Lies
# 3. Romy and Michele's High School Reunion - The Three Musketeers
# 4. Anastasia - Stargate
# 5. Grosse Pointe Blank - Money Train
# 6. The Fifth Element - Under Siege
# 7. Starship Troopers - Full Metal Jacket
# 8. Wild America - Days of Thunder
# 9. Batman Returns - Batman Forever
# 10. Batman - Under Siege 2: Dark Territory
# PID:18; count/total:1/2=0.5
#
# GT:Congo
# predictions:1. The Omen - Twelve Monkeys
# 2. The Believers - The Game
# 3. Bram Stoker's Dracula - Tales from the Crypt Presents: Bordello of Blood
# 4. Body Snatchers - Scream
# 5. Cape Fear - Evil Dead II
# 6. Frisk - Fargo
# 7. The Howling - Carrie
# 8. The Shining - Screamers
# 9. The Omen - Bride of Frankenstein
# 10. The Believers - Aliens
# PID:20; count/total:1/3=0.3333333333333333
#
# GT:Toy Story
# predictions:1. Face/Off - Eraser starring John Travolta and Arnold Schwarzenegger.
# 8. A Grand Day Out - Groundhog Day
# PID:382; count/total:32/62=0.5161290322580645
#
# GT:Return of the Jedi
# predictions:1. Toy Story - Beavis and Butt-head Do America
# 2. Bound - Chasing Amy
# 3. Leaving Las Vegas - Heat
# 4. Welcome to the Dollhouse - Secrets & Lies
# 5. Trainspotting - Mission: Impossible
# 6. The English Patient - Twelve Monkeys
# 7. The Godfather - Return of the Jedi
# 8. Scream - Men in Black
# 9. Mr. Holland's Opus - Jerry Maguire
# 10. Face/Off - Sabrina
# PID:387; count/total:33/63=0.5238095238095238
#
# GT:Cool Hand Luke
# predictions:1. Die Hard - Star Wars
# 2. The Godfather: Part II - The Godfather
# 3. Casablanca - The Maltese Falcon
# 4. Manon of the Spring (Manon des sources) - Back to the Future
# 5. The Shawshank Redemption - Fargo
# 6. Cinema Paradiso - Highlander
# 7. The Fugitive - The Usual Suspects
# 8. The Great Escape - Cool Hand Luke
# 9. Psycho - The Silence of the Lambs
# 10. Blade Runner - Alien
# PID:389; count/total:34/64=0.53125
#
# GT:Fargo
# predictions:1. The Celluloid Closet - Swingers (starring Vince Vaughn and Jon Favreau).
# 2. Richard III - The Birdcage (starring Robin Williams and Nathan Lane).
# 3. Star Wars - Face/Off (starring John Travolta and Nicolas Cage).
# 4. The Convent - Twelve Monkeys (starring Bruce Willis and Brad Pitt).
# 5. Primal Fear - Donnie Brasco (starring Al Pacino and Johnny Depp).
# 6. Leaving Las Vegas - Ulee's Gold (starring Peter Fonda).
# 7. Everyone Says I Love You - The Godfather (starring Marlon Brando and Al Pacino).
# 8. The English Patient - Antonia's Line (starring Willeke van Ammelrooy and Els Dottermans).
# 9. Jerry Maguire (starring Tom Cruise and Renée Zellweger).
# 10. Toy Story (starring Tom Hanks and Tim Allen).
# PID:406; count/total:34/65=0.5230769230769231
#
# GT:The Big Lebowski
# predictions:1. The Daytrippers - The Full Monty
# 2. Dracula: Dead and Loving It - The Wedding Singer
# 3. Sliver - The Game
# 4. Ace Ventura: When Nature Calls - The Big Lebowski
# 5. The Substitute - Red Corner
# 6. Judge Dredd - Air Force One
# 7. Beverly Hills Cop III - In & Out
# 8. Daylight - The Rainmaker
# 9. The English Patient - Seven Years in Tibet
# 10. Chasing Amy - Ulee's Gold
# PID:412; count/total:35/66=0.5303030303030303
#
# GT:Liar Liar
# predictions:1. Bean - The Full Monty
# 2. Rosewood - The Peacemaker
# 3. Incognito - The Saint
# 4. Air Force One - The Devil's Own
# 5. The Ice Storm - Mother
# 6. Career Girls - Chasing Amy
# 7. L.A. Confidential - Conspiracy Theory
# 8. Gattaca - Evita
# 9. Dante's Peak - Murder at 1600
# 10. Soul Food - George of the Jungle
# PID:414; count/total:35/67=0.5223880597014925
#
# GT:Raiders of the Lost Ark
# predictions:1. Walk in the Clouds - The Princess Bride
# 2. A - Pulp Fiction
# 3. Rob Roy - The Fugitive
# 4. Pretty Woman - Speed
# 5. Ghost - Groundhog Day
# 6. Dave - When Harry Met Sally...
# 7. Legends of the Fall - Raiders of the Lost Ark
# 8. The Bridges of Madison County - Jerry Maguire
# 9. The American President - Mary Poppins
# 10. The Nightmare Before Christmas - Alice in Wonderland
# PID:419; count/total:36/68=0.5294117647058824
#
# GT:Jerry Maguire
# predictions:1. Dante's Peak - Mission: Impossible (Tom Cruise).
# 2. I Know What You Did Last Summer - Scream (Neve Campbell, Courteney Cox, and David Arquette).
# 3. Crash - The Long Kiss Goodnight (Sandra Bullock).
# 4. Liar Liar - Jerry Maguire (Jim Carrey).
# 5. Scream - I Know What You Did Last Summer (Jennifer Love Hewitt, Sarah Michelle Gellar, and Ryan Phillippe).
# 6. The Edge - The Saint (Anthony Hopkins).
# 7. The Game - The Frighteners (Michael J. Fox).
# 8. The Devil's Own - Air Force One (Harrison Ford).
# 9. Men in Black - Independence Day (ID4) (Will Smith).
# 10. Willy Wonka and the Chocolate Factory - Time to Kill (Gene Wilder).
# PID:427; count/total:37/69=0.5362318840579711
#
# GT:Star Trek: First Contact
# predictions:1. Mighty Aphrodite - Grosse Pointe Blank (John Cusack, Minnie Driver).
# 2. Toy Story - The Frighteners (Michael J. Fox).
# 3. Return of the Jedi - Star Trek: First Contact (Patrick Stewart, Brent Spiner).
# 4. Rumble in the Bronx - Ransom (Mel Gibson).
# 5. Star Wars - Mission: Impossible (Tom Cruise).
# 6. Mother - The Truth About Cats & Dogs (Uma Thurman, Janeane Garofalo).
# 7. Liar Liar - Men in Black (Will Smith, Tommy Lee Jones).
# 8. Contact - Independence Day (ID4) (Will Smith, Jeff Goldblum).
# 9. Courage Under Fire (Denzel Washington).
# 10. Sleepers (Robert De Niro, Brad Pitt).
# PID:428; count/total:38/70=0.5428571428571428
#
# GT:Star Wars
# predictions:1. The Manchurian Candidate - The Usual Suspects (Starring Kevin Spacey and Gabriel Byrne).
# 2. Full Metal Jacket - The Terminator (Starring Arnold Schwarzenegger and Michael Biehn).
# 3. Harold and Maude - Annie Hall (Starring Woody Allen and Diane Keaton).
# 4. Rear Window - Psycho (Starring Anthony Perkins and Janet Leigh).
# 5. Reservoir Dogs - GoodFellas (Starring Robert De Niro and Joe Pesci).
# 6. Dead Man Walking - The Silence of the Lambs (Starring Jodie Foster and Anthony Hopkins).
# 7. Raising Arizona - Back to the Future (Starring Michael J. Fox and Christopher Lloyd).
# 8. Apollo 13 - Contact (Starring Jodie Foster and Matthew McConaughey).
# PID:435; count/total:38/71=0.5352112676056338
#
# GT:George of the Jungle
# predictions:1. Starship Troopers - Alien: Resurrection
# 2. The Game - The Devil's Advocate
# 3. Contact - Gattaca
# 4. Bean - The MatchMaker
# 5. FairyTale: A True Story - Picture Perfect
# 6. Seven Years in Tibet - The English Patient
# 7. The Rainmaker - L.A. Confidential
# 8. Scream - Boogie Nights
# PID:438; count/total:38/72=0.5277777777777778
#
# GT:Cop Land
# predictions:1. Seven Years in Tibet - The Edge (Adventure drama starring Anthony Hopkins and Alec Baldwin).
# 2. Scream - The Devil's Advocate (Horror drama starring Keanu Reeves and Al Pacino).
# 3. Starship Troopers - Gattaca (Sci-fi drama starring Ethan Hawke and Uma Thurman).
# PID:479; count/total:42/78=0.5384615384615384
#
# GT:Braveheart
# predictions:1. Dead Poets Society - Much Ado About Nothing (Drama starring Kenneth Branagh, Emma Thompson, and Denzel Washington).
# 2. Speed - Raising Arizona (Comedy starring Nicolas Cage, Holly Hunter, and John Goodman).
# 3. Being There - The Wrong Trousers (Animation starring Peter Sallis, Richard Grant, and Sheila Steafel).
# 4. Schindler's List - Braveheart (Drama/Historical starring Mel Gibson, Sophie Marceau, and Patrick McGoohan).
# 5. Groundhog Day - Four Weddings and a Funeral (Comedy starring Hugh Grant, Andie MacDowell, and Kristin Scott Thomas).
# 6. Arsenic and Old Lace - Sabrina (Romance/Comedy starring Humphrey Bogart, Audrey Hepburn, and William Holden).
# 7. Liar Liar - Get Shorty (Comedy/Crime starring John Travolta, Gene Hackman, and Rene Russo).
# 8. Air Force One - The Sting (Crime/Drama starring Paul Newman, Robert Redford, and Robert Shaw).
# PID:498; count/total:43/79=0.5443037974683544
#
# GT:Dante's Peak
# predictions:1. Ulee's Gold - The Apostle
# 2. Kolya - Jackie Brown
# 3. Good Will Hunting - Boogie Nights
# 4. Air Force One - The Peacemaker
# 5. L.A. Confidential - Conspiracy Theory
# 6. The English Patient - Seven Years in Tibet
# 7. Titanic - Evita
# 8. Gattaca - Apt Pupil
# PID:500; count/total:43/80=0.5375
#
# GT:Jackie Brown
# predictions:1. Mad City - The Devil's Advocate (starring John Travolta and Dustin Hoffman).
# 2. Lost Highway - U Turn (starring Bill Pullman and Patricia Arquette).
# 3. Kiss the Girls - The Devil's Own (starring Morgan Freeman and Ashley Judd).
# 4. Titanic - Evita (starring Leonardo DiCaprio and Kate Winslet).
# 5. Cop Land - G.I. Jane (starring Sylvester Stallone and Robert De Niro).
# 6. The Game - The Apostle (starring Michael Douglas and Sean Penn).
# 7. Scream - Liar Liar (starring Neve Campbell and Courteney Cox).
# 8. Chasing Amy - In & Out (starring Ben Affleck and Joey Lauren Adams).
# 9. Jackie Brown (starring Pam Grier and Samuel L. Jackson).
# 10. L.A. Confidential (starring Kevin Spacey and Russell Crowe).
# PID:501; count/total:44/81=0.5432098765432098
#
# GT:The Jackal
# predictions:1. Boogie Nights - Everyone Says I Love You
# 2. Contact - Gattaca
# 3. Chasing Amy - The Edge
# 4. Titanic - Red Corner
# 5. Lost Highway - The Jackal
# 6. The Game - Wag the Dog
# 7. The Devil's Advocate - The Saint
# 8. The English Patient - Apt Pupil
# 9. Rosewood - Soul Food
# 10. Amistad - The Full Monty
# PID:506; count/total:45/82=0.5487804878048781
#
# GT:Contact
# predictions:1. The Godfather - L.A. Confidential
# 2. Star Wars - Men in Black
# 3. Dead Man Walking - Ulee's Gold
# 4. Postino, Il - Big Night
# 5. A Close Shave - Boot
# 6. Return of the Jedi - Air Force One
# 7. Beautiful Thing - Sense and Sensibility
# 8. The English Patient - Emma
# 9. Jerry Maguire - Liar Liar
# 10. Contact - Twelve Monkeys
# PID:510; count/total:46/83=0.5542168674698795
#
# GT:Courage Under Fire
# predictions:1. Heaven's Prisoners - Absolute Power
# 5. Apt Pupil - Boogie Nights (Drama starring Mark Wahlberg, Julianne Moore, and Burt Reynolds).
# 6. The Edge - Wag the Dog (Comedy starring Robert De Niro and Dustin Hoffman).
# 7. The Apostle - The Saint (Action/Thriller starring Val Kilmer).
# 8. The Game - Evita (Musical starring Madonna, Antonio Banderas, and Jonathan Pryce).
# 9. Mother - Good Will Hunting (Drama starring Matt Damon and Robin Williams).
# 10. Desperate Measures - The Devil's Own (Action/Thriller starring Harrison Ford and Brad Pitt).
# PID:845; count/total:77/149=0.5167785234899329
#
# GT:One Flew Over the Cuckoo's Nest
# predictions:1. Fried Green Tomatoes - Being There
# 2. Boot - Das
# 3. Das - Boot
# 4. The English Patient - Sabrina
# 5. The Fifth Element - The Graduate
# 6. Star Wars - The Empire Strikes Back
# 7. The Big Lebowski - Raising Arizona
# 8. Return of the Jedi - Star Trek: First Contact
# 9. The Rainmaker - The Silence of the Lambs
# 10. The Shawshank Redemption - One Flew Over the Cuckoo's Nest
# PID:847; count/total:78/150=0.52
#
# GT:Jerry Maguire
# predictions:1. Event Horizon - The Frighteners
# 2. Spawn - Men in Black
# 3. As Good As It Gets - Jerry Maguire
# 4. Kull the Conqueror - Time to Kill
# 5. The Saint - The Long Kiss Goodnight
# 6. In & Out - Chasing Amy
# 7. Dante's Peak - Jaws
# 8. G.I. Jane - The Empire Strikes Back
# 9. Liar Liar - GoodFellas
# 10. Willy Wonka and the Chocolate Factory - The Silence of the Lambs
# PID:859; count/total:79/151=0.5231788079470199
#
# GT:Jackie Brown
# predictions:1. Gattaca - Boogie Nights (Drama starring Mark Wahlberg and Julianne Moore).
# 2. Amistad - The Devil's Advocate (Drama starring Keanu Reeves and Al Pacino).
# 3. Chasing Amy - The Game (Thriller starring Michael Douglas and Sean Penn).
# 4. The Peacemaker - The Edge (Action thriller starring Anthony Hopkins and Alec Baldwin).
# 5. Tomorrow Never Dies - The Saint (Spy thriller starring Val Kilmer and Elisabeth Shue).
# 6. Eve's Bayou - Jackie Brown (Crime drama starring Samuel L. Jackson and Pam Grier).
# 7. Career Girls - Ulee's Gold (Drama starring Peter Fonda and Patricia Richardson).
# 8. The Apostle - The Full Monty (Comedy starring Robert Carlyle and Tom Wilkinson).
# PID:864; count/total:80/152=0.5263157894736842
#
# GT:Boogie Nights
# predictions:1. Good Will Hunting - As Good As It Gets
# 2. Ulee's Gold - Wag the Dog
# 3. L.A. Confidential - Murder at 1600
# 4. Amistad - The Devil's Own
# 5. Air Force One - The Jackal
# 6. Apt Pupil - Deconstructing Harry
# 7. Titanic - Everyone Says I Love You
# 8. The English Patient - Evita
# 9. Scream - I Know What You Did Last Summer
# 10. Mad City - Boogie Nights
# PID:866; count/total:81/153=0.5294117647058824
#
# GT:The Shawshank Redemption
# predictions:1. Conspiracy Theory - Star Trek: The Wrath of Khan.
# 2. Amistad - The Godfather.
# 3. Wag the Dog - Pulp Fiction.
# 4. Murder at 1600 - North by Northwest.
# 5. The Postman - Apollo 13.
# 6. As Good As It Gets - Leaving Las Vegas.
# 7. Liar Liar - Toy Story.
# 8. Fly Away Home - The African Queen.
# 9. Lawrence of Arabia - Vertigo.
# 10. E.T. the Extra-Terrestrial - Aliens.
# PID:871; count/total:81/154=0.525974025974026
#
# GT:Scream
# predictions:1. L.A. Confidential - Jackie Brown (starring Robert De Niro and Pam Grier).
# 2. The Full Monty - The Edge (starring Anthony Hopkins and Alec Baldwin).
# 3. Titanic - Evita (starring Madonna and Antonio Banderas).
# 4. Deconstructing Harry - As Good As It Gets (starring Jack Nicholson and Helen Hunt).
# 5. Kundun - Seven Years in Tibet (starring Brad Pitt and David Thewlis).
# 6. Everyone Says I Love You - Cop Land (starring Sylvester Stallone and Robert De Niro).
# 7. Good Will Hunting - Desperate Measures (starring Michael Keaton and Andy Garcia).
# 8. Apt Pupil - Red Corner (starring Richard Gere and Bai Ling).
# 9. The English Patient - The Rainmaker (starring Matt Damon and Danny DeVito).
# 10. The Ice Storm - Kiss the Girls (starring Morgan Freeman and Ashley Judd).
# PID:872; count/total:81/155=0.5225806451612903
#
# GT:Titanic
# predictions:1. G.I. Jane - The Peacemaker (Action/Drama starring George Clooney and Nicole Kidman).
# 2. The Devil's Own - The Jackal (Thriller starring Bruce Willis and Richard Gere).
# 3. Gattaca - The Saint (Sci-Fi starring Val Kilmer and Elisabeth Shue).
# 4. Air Force One - Murder at 1600 (Action/Thriller starring Harrison Ford and Diane Lane).
# 5. Conspiracy Theory - Liar Liar (Comedy starring Jim Carrey and Maura Tierney).
# 6. In & Out - Ulee's Gold (Drama starring Peter Fonda and Patricia Richardson).
# 7. The Edge - Seven Years in Tibet (Adventure/Thriller starring Brad Pitt and David Thewlis).
# 8. Boogie Nights - Evita (Musical starring Madonna and Antonio Banderas).
# 9. The Rainmaker (Drama starring Matt Damon and Danny DeVito).
# 10. Red Corner (Thriller starring Richard Gere and Bai Ling).
# PID:873; count/total:81/156=0.5192307692307693
#
# GT:The Saint
# predictions:1. Ayn Rand: A Sense of Life - L.A. Confidential
# 2. The English Patient - Evita
# 3. The Rainmaker - The Peacemaker
# 4. Good Will Hunting - Boogie Nights
# 5. Titanic - Tomorrow Never Dies
# 6. The Edge - Mad City
# 7. Wag the Dog - The Full Monty
# 8. Apt Pupil - Desperate Measures
# 9. The Saint - Ulee's Gold
# 10. Dante's Peak - Cop Land
# PID:874; count/total:82/157=0.5222929936305732
#
# GT:Waterworld
# predictions:1. GoodFellas - True Lies
# 2. The Good, The Bad and The Ugly - The Quick and the Dead
# 3. Ben-Hur - The Last of the Mohicans
# 4. Conan the Barbarian - The Terminator
# 5. Butch Cassidy and the Sundance Kid - The Shadow
# 6. Under Siege - Mission: Impossible
# 7. The Magnificent Seven - Money Train
# 8. Highlander - Aliens
# 9. The Hunt for Red October - Star Trek IV: The Voyage Home
# 10. Bad Boys - Broken Arrow
# PID:875; count/total:82/158=0.5189873417721519
#
# GT:Event Horizon
# predictions:1. Rocket Man - The Game
# 2. Hoodlum - L.A. Confidential
# 3. Chasing Amy - The Devil's Advocate
# 4. Air Force One - Desperate Measures
# 5. The Wedding Singer - Bean
# 6. Titanic - The English Patient
# 7. Scream - Event Horizon
# 8. The Edge - Wag the Dog
